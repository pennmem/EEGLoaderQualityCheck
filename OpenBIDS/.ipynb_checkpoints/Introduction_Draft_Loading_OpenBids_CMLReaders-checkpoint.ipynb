# %% [markdown]
# # Accessing OpenBIDS for CML Data
# This tutorial shows how to load behavioral and EEG data in OpenBIDS format so it matches the structure used by the Computational Memory Lab’s CMLReader package. The structure is designed to support new analyses and replicate existing scripts with minimal changes.

# %%
# imports
import pandas as pd; pd.set_option('display.max_columns', None)
import cmlreaders as cml
import numpy as np
import xarray as xr
from mne_bids import BIDSPath, read_raw_bids, get_entity_vals
import os
import mne
from ptsa.data.timeseries import TimeSeries

# %% [markdown]
# ## Loading Behavioral Data

# %% [markdown]
# ### CMLReader
#
# As a reminder, to load behavioral data for a given experimental session, we select the session using its subject, experiment, and session identifiers, instantiate a CMLReader object, and then load the desired data type (e.g., events).

# %%
# load dataframe of all sessions
df = cml.get_data_index()
df[:10]                     # show the first 10 entries
# Out:
#   Recognition                                         all_events contacts  \
# 0         NaN  protocols/ltp/subjects/LTP001/experiments/Valu...      NaN
# 1         NaN  protocols/ltp/subjects/LTP063/experiments/ltpF...      NaN
# 2         NaN  protocols/ltp/subjects/LTP063/experiments/ltpF...      NaN
# 3         NaN  protocols/ltp/subjects/LTP063/experiments/ltpF...      NaN
# 4         NaN  protocols/ltp/subjects/LTP063/experiments/ltpF...      NaN
# 5         NaN  protocols/ltp/subjects/LTP063/experiments/ltpF...      NaN
# 6         NaN  protocols/ltp/subjects/LTP063/experiments/ltpF...      NaN
# 7         NaN  protocols/ltp/subjects/LTP063/experiments/ltpF...      NaN
# 8         NaN  protocols/ltp/subjects/LTP063/experiments/ltpF...      NaN
# 9         NaN  protocols/ltp/subjects/LTP063/experiments/ltpF...      NaN
#
#      experiment import_type  localization  \
# 0  ValueCourier       build             0
# 1         ltpFR       build             0
# 2         ltpFR       build             0
# 3         ltpFR       build             0
# 4         ltpFR       build             0
# 5         ltpFR       build             0
# 6         ltpFR       build             0
# 7         ltpFR       build             0
# 8         ltpFR       build             0
# 9         ltpFR       build             0
#
#                                          math_events  montage  \
# 0                                                NaN        0
# 1  protocols/ltp/subjects/LTP063/experiments/ltpF...        0
# 2  protocols/ltp/subjects/LTP063/experiments/ltpF...        0
# 3  protocols/ltp/subjects/LTP063/experiments/ltpF...        0
# 4  protocols/ltp/subjects/LTP063/experiments/ltpF...        0
# 5  protocols/ltp/subjects/LTP063/experiments/ltpF...        0
# 6  protocols/ltp/subjects/LTP063/experiments/ltpF...        0
# 7  protocols/ltp/subjects/LTP063/experiments/ltpF...        0
# 8  protocols/ltp/subjects/LTP063/experiments/ltpF...        0
# 9  protocols/ltp/subjects/LTP063/experiments/ltpF...        0
#
#   original_experiment original_session pairs ps4_events  session subject  \
# 0                 NaN                0   NaN        NaN        0  LTP001
# 1                 NaN                0   NaN        NaN        0  LTP063
# 2                 NaN                1   NaN        NaN        1  LTP063
# 3                 NaN               10   NaN        NaN       10  LTP063
# 4                 NaN               11   NaN        NaN       11  LTP063
# 5                 NaN               12   NaN        NaN       12  LTP063
# 6                 NaN               13   NaN        NaN       13  LTP063
# 7                 NaN               14   NaN        NaN       14  LTP063
# 8                 NaN               15   NaN        NaN       15  LTP063
# 9                 NaN               16   NaN        NaN       16  LTP063
#
#   subject_alias  system_version  \
# 0        LTP001             NaN
# 1        LTP063             NaN
# 2        LTP063             NaN
# 3        LTP063             NaN
# 4        LTP063             NaN
# 5        LTP063             NaN
# 6        LTP063             NaN
# 7        LTP063             NaN
# 8        LTP063             NaN
# 9        LTP063             NaN
#
#                                          task_events
# 0  protocols/ltp/subjects/LTP001/experiments/Valu...
# 1  protocols/ltp/subjects/LTP063/experiments/ltpF...
# 2  protocols/ltp/subjects/LTP063/experiments/ltpF...
# 3  protocols/ltp/subjects/LTP063/experiments/ltpF...
# 4  protocols/ltp/subjects/LTP063/experiments/ltpF...
# 5  protocols/ltp/subjects/LTP063/experiments/ltpF...
# 6  protocols/ltp/subjects/LTP063/experiments/ltpF...
# 7  protocols/ltp/subjects/LTP063/experiments/ltpF...
# 8  protocols/ltp/subjects/LTP063/experiments/ltpF...
# 9  protocols/ltp/subjects/LTP063/experiments/ltpF...

# %%
df_PS2 = df.query("experiment == 'FR1'").iloc[0]
df_PS2
# Out:
# Recognition                                                          NaN
# all_events             protocols/r1/subjects/R1001P/experiments/FR1/s...
# contacts               protocols/r1/subjects/R1001P/localizations/0/m...
# experiment                                                           FR1
# import_type                                                        build
# localization                                                           0
# math_events            protocols/r1/subjects/R1001P/experiments/FR1/s...
# montage                                                                0
# original_experiment                                                  NaN
# original_session                                                       0
# pairs                  protocols/r1/subjects/R1001P/localizations/0/m...
# ps4_events                                                           NaN
# session                                                                0
# subject                                                           R1001P
# subject_alias                                                     R1001P
# system_version                                                       NaN
# task_events            protocols/r1/subjects/R1001P/experiments/FR1/s...
# Name: 8, dtype: object

# %%
cmlreader = cml.CMLReader(subject=df_PS2['subject'], experiment=df_PS2['experiment'], session=df_PS2['session'])
# load the behavioral events
evs_PS2 = cmlreader.load('pairs')

# %%
evs_PS2
# Out:
#     contact_1  contact_2      label           id  is_explicit  is_stim_only  \
# 0           2          3  LAF1-LAF2  laf.1-laf.2        False         False
# 1           3          4  LAF2-LAF3  laf.2-laf.3        False         False
# 2           4          5  LAF3-LAF4  laf.3-laf.4        False         False
# 3           5          6  LAF4-LAF5  laf.4-laf.5        False         False
# 4           6          7  LAF5-LAF6  laf.5-laf.6        False         False
# ..        ...        ...        ...          ...          ...           ...
# 67         90         91    RP3-RP4    rp.3-rp.4        False         False
# 68         91         92    RP4-RP5    rp.4-rp.5        False         False
# 69         92         93    RP5-RP6    rp.5-rp.6        False         False
# 70         93         94    RP6-RP7    rp.6-rp.7        False         False
# 71         94         95    RP7-RP8    rp.7-rp.8        False         False
#
#    type_1 type_2            avg.region   avg.x   avg.y   avg.z  \
# 0       S      S  rostralmiddlefrontal -41.205  52.315   4.545
# 1       S      S      parstriangularis -47.010  42.985   2.890
# 2       S      S      parstriangularis -51.680  33.215   1.260
# 3       S      S      parstriangularis -54.300  22.630  -0.890
# 4       S      S      superiortemporal -56.380  12.085  -2.980
# ..    ...    ...                   ...     ...     ...     ...
# 67      S      S           postcentral  48.760 -31.595  54.150
# 68      S      S         supramarginal  55.140 -30.045  45.440
# 69      S      S         supramarginal  59.990 -28.425  35.470
# 70      S      S         supramarginal  62.765 -27.405  24.635
# 71      S      S      superiortemporal  62.780 -26.065  13.600
#
#         avg.dural.region  avg.dural.x  avg.dural.y  avg.dural.z  \
# 0   rostralmiddlefrontal   -39.192639    50.946599     4.152569
# 1   rostralmiddlefrontal   -44.917132    42.021149     2.935475
# 2       parstriangularis   -51.443475    32.776203     0.906133
# 3       parstriangularis   -53.127559    20.610749     1.078647
# 4       superiortemporal   -54.827944     9.408506    -1.535033
# ..                   ...          ...          ...          ...
# 67           postcentral    49.143819   -31.793900    53.966040
# 68         supramarginal    57.377527   -30.900330    45.517476
# 69         supramarginal    62.212215   -29.187280    35.959248
# 70         supramarginal    61.760509   -26.655133    25.863125
# 71      superiortemporal    61.790658   -24.958660    16.140355
#
#                dk.region  dk.x  dk.y  dk.z            ind.region   ind.x  \
# 0   rostralmiddlefrontal   NaN   NaN   NaN  rostralmiddlefrontal -32.685
# 1   rostralmiddlefrontal   NaN   NaN   NaN  rostralmiddlefrontal -38.360
# 2       parstriangularis   NaN   NaN   NaN      parstriangularis -43.045
# 3       parstriangularis   NaN   NaN   NaN      parstriangularis -45.965
# 4       superiortemporal   NaN   NaN   NaN      parstriangularis -48.395
# ..                   ...   ...   ...   ...                   ...     ...
# 67         supramarginal   NaN   NaN   NaN         supramarginal  44.680
# 68         supramarginal   NaN   NaN   NaN         supramarginal  50.145
# 69         supramarginal   NaN   NaN   NaN         supramarginal  54.220
# 70                   NaN   NaN   NaN   NaN         supramarginal  56.395
# 71                   NaN   NaN   NaN   NaN      superiortemporal  56.120
#
#      ind.y   ind.z      ind.dural.region  ind.dural.x  ind.dural.y  \
# 0   55.775   3.955  rostralmiddlefrontal   -32.235608    55.932797
# 1   47.775   2.135  rostralmiddlefrontal   -37.853853    47.793965
# 2   39.310   0.275      parstriangularis   -43.924270    40.200576
# 3   30.025  -2.170      parstriangularis   -46.317560    30.780520
# 4   20.745  -4.580      parstriangularis   -47.983551    20.135994
# ..     ...     ...                   ...          ...          ...
# 67 -27.855  40.820         supramarginal    44.980843   -27.691719
# 68 -26.295  32.815         supramarginal    51.599941   -26.098420
# 69 -24.515  23.735         supramarginal    55.418203   -24.499221
# 70 -23.115  13.920         supramarginal    56.266446   -23.261644
# 71 -21.255   4.040      superiortemporal    56.193680   -21.291114
#
#     ind.dural.z tal.region     tal.x     tal.y      tal.z stein.region  \
# 0      4.261411       None -41.03220  59.64390   3.984425          NaN
# 1      2.376036       None -47.39695  50.17595   2.985235          NaN
# 2      0.121013       None -52.58225  40.20585   2.020270          NaN
# 3     -2.236336       None -55.65790  29.22995   0.533825          NaN
# 4     -5.284738       None -58.16045  18.28200  -0.864941          NaN
# ..          ...        ...       ...       ...        ...          ...
# 67    41.455778       None  53.18375 -22.11445  59.026000          NaN
# 68    34.332248       None  59.58060 -22.20950  49.813200          NaN
# 69    25.150691       None  64.33270 -22.35900  39.325900          NaN
# 70    14.763449       None  66.86295 -23.15485  28.022650          NaN
# 71     6.085045       None  66.49435 -23.52640  16.543150          NaN
#
#     stein.x  stein.y  stein.z das.region  das.x  das.y  das.z     mni.x  \
# 0       NaN      NaN      NaN        NaN    NaN    NaN    NaN -42.94905
# 1       NaN      NaN      NaN        NaN    NaN    NaN    NaN -50.44460
# 2       NaN      NaN      NaN        NaN    NaN    NaN    NaN -55.93230
# 3       NaN      NaN      NaN        NaN    NaN    NaN    NaN -57.79805
# 4       NaN      NaN      NaN        NaN    NaN    NaN    NaN -58.72950
# ..      ...      ...      ...        ...    ...    ...    ...       ...
# 67      NaN      NaN      NaN        NaN    NaN    NaN    NaN  54.89260
# 68      NaN      NaN      NaN        NaN    NaN    NaN    NaN  58.75835
# 69      NaN      NaN      NaN        NaN    NaN    NaN    NaN  63.29850
# 70      NaN      NaN      NaN        NaN    NaN    NaN    NaN  66.20690
# 71      NaN      NaN      NaN        NaN    NaN    NaN    NaN  65.55995
#
#        mni.y      mni.z
# 0   56.40660   0.507948
# 1   47.53225  -0.108563
# 2   37.48010   1.210089
# 3   27.55355   0.529655
# 4   18.82430  -2.609848
# ..       ...        ...
# 67 -28.95750  51.072577
# 68 -26.06735  43.368032
# 69 -23.67250  31.908984
# 70 -23.55400  19.837947
# 71 -23.92135  10.549864
#
# [72 rows x 43 columns]

# %%
bids_root = "/data/BIDS/FR1"

bp = BIDSPath(
    subject="R1111M",
    session="0",
    datatype="ieeg",
    suffix="electrodes",
    extension=".tsv",
    root=bids_root,
    check=False
)

elec = pd.read_csv(bp.fpath, sep="\t")
elec.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 13
#       1 bids_root = "/data/BIDS/FR1"
#       3 bp = BIDSPath(
#       4     subject="R1001P",
#       5     session="0",
#    (...)
#      10     check=False
#      11 )
# ---> 13 elec = pd.read_csv(bp.fpath, sep="\t")
#      14 elec.head()
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/BIDS/FR1/sub-R1001P/ses-0/ieeg/sub-R1001P_ses-0_electrodes.tsv'

# %%
# let's find subjects who did the ValueCourier experiment
VC_df = df.query("experiment == 'ValueCourier'")
VC_df['subject'].unique()[:20]
# Out:
# array(['LTP001', 'LTP606', 'LTP607', 'LTP609', 'LTP610', 'LTP612',
#        'LTP613', 'LTP614', 'LTP9992', 'LTP9993'], dtype=object)

# %%
# we'll pick LTP606 and select out this subject's ValueCourier sessions
sub_scalp = 'LTP606'
exp_scalp = 'ValueCourier'
df_select = df[(df['subject'] == sub_scalp) & (df['experiment'] == exp_scalp)]
display(df_select); print(f'{sub_scalp} sessions: {np.array(df_select.session)}')
# Out:
#      Recognition                                         all_events contacts  \
# 7696         NaN  protocols/ltp/subjects/LTP606/experiments/Valu...      NaN
# 7697         NaN  protocols/ltp/subjects/LTP606/experiments/Valu...      NaN
# 7698         NaN  protocols/ltp/subjects/LTP606/experiments/Valu...      NaN
# 7699         NaN  protocols/ltp/subjects/LTP606/experiments/Valu...      NaN
# 7700         NaN  protocols/ltp/subjects/LTP606/experiments/Valu...      NaN
# 7701         NaN  protocols/ltp/subjects/LTP606/experiments/Valu...      NaN
#
#         experiment import_type  localization math_events  montage  \
# 7696  ValueCourier       build             0         NaN        0
# 7697  ValueCourier       build             0         NaN        0
# 7698  ValueCourier       build             0         NaN        0
# 7699  ValueCourier       build             0         NaN        0
# 7700  ValueCourier       build             0         NaN        0
# 7701  ValueCourier       build             0         NaN        0
#
#      original_experiment original_session pairs ps4_events  session subject  \
# 7696                 NaN                0   NaN        NaN        0  LTP606
# 7697                 NaN                1   NaN        NaN        1  LTP606
# 7698                 NaN                2   NaN        NaN        2  LTP606
# 7699                 NaN                3   NaN        NaN        3  LTP606
# 7700                 NaN                4   NaN        NaN        4  LTP606
# 7701                 NaN                5   NaN        NaN        5  LTP606
#
#      subject_alias  system_version  \
# 7696        LTP606             NaN
# 7697        LTP606             NaN
# 7698        LTP606             NaN
# 7699        LTP606             NaN
# 7700        LTP606             NaN
# 7701        LTP606             NaN
#
#                                             task_events
# 7696  protocols/ltp/subjects/LTP606/experiments/Valu...
# 7697  protocols/ltp/subjects/LTP606/experiments/Valu...
# 7698  protocols/ltp/subjects/LTP606/experiments/Valu...
# 7699  protocols/ltp/subjects/LTP606/experiments/Valu...
# 7700  protocols/ltp/subjects/LTP606/experiments/Valu...
# 7701  protocols/ltp/subjects/LTP606/experiments/Valu...
# LTP606 sessions: [0 1 2 3 4 5]

# %%
# lets load the data from the first session
df_sess = df_select.iloc[0]         # select 1 row

# instantiate a Reader object using session metadata
# subjects beginning with 'LTP' are scalp subjects, so we don't need to specify the localization and montage
cmlreader = cml.CMLReader(subject=df_sess['subject'], experiment=df_sess['experiment'], session=df_sess['session'])
# load the behavioral events
evs_cml = cmlreader.load('events')
evs_cml[:10]
# Out:
#    eegoffset  actualvalue  compensation  correctPointingDirection  \
# 0      23440       -999.0      8.461538                      -999
# 1      31922       -999.0      8.461538                      -999
# 2     468068       -999.0      8.461538                      -999
# 3     646089       -999.0      8.461538                      -999
# 4     646183       -999.0      8.461538                      -999
# 5    1724585       -999.0      8.461538                      -999
# 6    1725717       -999.0      8.461538                      -999
# 7    1731210       -999.0      8.461538                      -999
# 8    1763086       -999.0      8.461538                      -999
# 9    1766295       -999.0      8.461538                      -999
#
#                                              eegfile  eogArtifact  \
# 0  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 1  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 2  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 3  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 4  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 5  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 6  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 7  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 8  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 9  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
#
#      experiment  finalrecalled  intruded  intrusion  item  itemno  itemvalue  \
# 0  ValueCourier           -999      -999       -999  -999    -999       -999
# 1  ValueCourier           -999      -999       -999  -999      -1       -999
# 2  ValueCourier           -999      -999       -999  -999      -1       -999
# 3  ValueCourier           -999      -999       -999  -999    -999       -999
# 4  ValueCourier           -999      -999       -999  -999    -999       -999
# 5  ValueCourier           -999      -999       -999  -999    -999       -999
# 6  ValueCourier           -999      -999       -999  -999    -999       -999
# 7  ValueCourier           -999      -999       -999  -999    -999       -999
# 8  ValueCourier           -999      -999       -999  -999    -999       -999
# 9  ValueCourier           -999      -999       -999  -999    -999       -999
#
#    montage  msoffset         mstime  multiplier  numingroupchosen phase  \
# 0        0        -1  1761665861795    0.846154                 4     1
# 1        0        -1  1761665865937    0.846154                 4     1
# 2        0        -1  1761666078916    0.846154                 4     1
# 3        0        -1  1761666165847    0.846154                 4     1
# 4        0        -1  1761666165893    0.846154                 4     1
# 5        0        -1  1761666692498    0.846154                 4     1
# 6        0        -1  1761666693051    0.846154                 4     1
# 7        0        -1  1761666695733    0.846154                 4     1
# 8        0        -1  1761666711299    0.846154                 4     1
# 9        0        -1  1761666712866    0.846154                 4     1
#
#    playerrotY     presX      presZ  primacybuf protocol  recalled  recencybuf  \
# 0      -999.0 -4.949219  10.500000           2      ltp      -999           3
# 1      -999.0 -4.949219  10.500000           2      ltp      -999           3
# 2      -999.0 -4.949219  10.500000           2      ltp      -999           3
# 3      -999.0 -4.949219  10.500000           2      ltp      -999           3
# 4      -999.0 -4.949219  10.500000           2      ltp      -999           3
# 5      -999.0 -3.000000   8.757812           2      ltp      -999           3
# 6      -999.0 -3.937500  11.757812           2      ltp      -999           3
# 7      -999.0 -3.953125  11.804688           2      ltp      -999           3
# 8      -999.0 -3.953125  11.804688           2      ltp      -999           3
# 9      -999.0 -3.953125  11.804688           2      ltp      -999           3
#
#    rectime  serialpos  session store  storeX  storeZ storepointtype subject  \
# 0     -999       -999        0  -999  -999.0  -999.0                 LTP606
# 1     -999       -999        0  -999  -999.0  -999.0                 LTP606
# 2     -999       -999        0  -999  -999.0  -999.0                 LTP606
# 3     -999       -999        0  -999  -999.0  -999.0                 LTP606
# 4     -999       -999        0  -999  -999.0  -999.0                 LTP606
# 5     -999       -999        0  -999  -999.0  -999.0                 LTP606
# 6     -999       -999        0  -999  -999.0  -999.0                 LTP606
# 7     -999       -999        0  -999  -999.0  -999.0                 LTP606
# 8     -999       -999        0  -999  -999.0  -999.0                 LTP606
# 9     -999       -999        0  -999  -999.0  -999.0                 LTP606
#
#    submittedPointingDirection  trial            type  valuerecall
# 0                        -999      0  store mappings         -999
# 1                        -999      0     VIDEO_START         -999
# 2                        -999      0      VIDEO_STOP         -999
# 3                        -999      0      SESS_START         -999
# 4                        -999      0        TL_START         -999
# 5                        -999      0          TL_END         -999
# 6                        -999      0      SESS_START         -999
# 7                        -999      0      SESS_START         -999
# 8                        -999      0      SESS_START         -999
# 9                        -999      0      SESS_START         -999

# %% [markdown]
# ### OpenBIDS
#
# To load behavioral data in OpenBIDS, we first set the root of the bids database. The database is structured as such:
#
# <pre>
# root/
# ├── sub-{subject_id}/
# │   └── ses-{session_id}/
# │       ├── beh/
# │       │   ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_beh.json
# │       │   └── sub-{subject_id}_ses-{session_id}_task-{experiment}_beh.tsv
# │       └── eeg/
# │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_eeg.bdf
# │           └── sub-{subject_id}_ses-{session_id}_task-{experiment}_events.tsv
# └── participants.tsv
# </pre>
#
# We can use the get_entity_vals functon from the mne_bids package to find all the subjects in the database. Once we have selected a subject, we can use the same function to find all sessions and experiments (called 'task' in OpenBIDS format) associated with that subject. Finally, we can find the .tsv file containing the behavioral data and load it into a Pandas Dataframe.

# %%
# set root
bids_root = "/data/LTP_BIDS/"

# %%
# let's find subjects loaded in the database
subjects = get_entity_vals(bids_root, "subject")
subjects
# Out:
# ['LTP063',
#  'LTP064',
#  'LTP065',
#  'LTP066',
#  'LTP067',
#  'LTP068',
#  'LTP069',
#  'LTP070',
#  'LTP073',
#  'LTP074',
#  'LTP093',
#  'LTP106',
#  'LTP115',
#  'LTP117',
#  'LTP122',
#  'LTP123',
#  'LTP133',
#  'LTP138',
#  'LTP187',
#  'LTP207',
#  'LTP229',
#  'LTP246',
#  'LTP260',
#  'LTP312',
#  'LTP327',
#  'LTP329',
#  'LTP339',
#  'LTP347',
#  'LTP354',
#  'LTP355',
#  'LTP606',
#  'LTP607',
#  'LTP609',
#  'LTP610',
#  'LTP612',
#  'LTP613',
#  'LTP614']

# %%
# now get the root of the subject and find which experiments they have completed
subject_root = os.path.join(bids_root, f"sub-LTP606")
tasks = get_entity_vals(subject_root, "task")
tasks
# Out:
# ['valuecourier']

# %%
# we can also see how many sessions they have completed
sessions = get_entity_vals(subject_root, "session")
sessions
# Out:
# ['0', '1', '2', '3', '4', '5']

# %%
# plug in the subject, task, and session info into BIDSPath and have the datatype set to "beh" to get the path to the .tsv file
# all inputs to BIDSPath should be strings so convert using the str() function
# load it using read_csv
subject = "LTP606"
task = tasks[0]
session = sessions[0]

path_bids = BIDSPath(
                subject=subject,
                session=str(session),
                task=task,  
                datatype="beh", 
                suffix="beh",
                extension=".tsv",
                root=bids_root
            )
evs_bids = pd.read_csv(path_bids.fpath, sep="\t")
evs_bids[:10]
evs_bids.columns
# Out:
# Index(['mstime', 'trial_type', 'stim_file', 'actualvalue', 'compensation',
#        'eegfile', 'eogArtifact', 'experiment', 'intruded', 'intrusion', 'item',
#        'itemno', 'itemvalue', 'montage', 'msoffset', 'multiplier',
#        'numingroupchosen', 'phase', 'playerrotY', 'presX', 'presZ',
#        'primacybuf', 'protocol', 'recalled', 'rectime', 'recencybuf',
#        'serialpos', 'session', 'store', 'storeX', 'storeZ', 'storepointtype',
#        'subject', 'trial', 'valuerecall'],
#       dtype='object')

# %%
evs_bids[evs_bids["trial_type"] == "WORD"]
# Out:
#       mstime trial_type                            stim_file  actualvalue  \
# 91   2765168   REC_WORD  wordpools/valuecourier_wordpool.txt    14.066667
# 92   2766506   REC_WORD  wordpools/valuecourier_wordpool.txt    14.066667
# 93   2767998   REC_WORD  wordpools/valuecourier_wordpool.txt    14.066667
# 94   2770338   REC_WORD  wordpools/valuecourier_wordpool.txt    14.066667
# 95   2772131   REC_WORD  wordpools/valuecourier_wordpool.txt    14.066667
# 96   2788693   REC_WORD  wordpools/valuecourier_wordpool.txt    14.066667
# 126  3399459   REC_WORD  wordpools/valuecourier_wordpool.txt    40.933334
# 127  3404663   REC_WORD  wordpools/valuecourier_wordpool.txt    40.933334
# 128  3424956   REC_WORD  wordpools/valuecourier_wordpool.txt    40.933334
# 129  3430096   REC_WORD  wordpools/valuecourier_wordpool.txt    40.933334
# 131  3450040   REC_WORD  wordpools/valuecourier_wordpool.txt    40.933334
# 132  3467577   REC_WORD  wordpools/valuecourier_wordpool.txt    40.933334
# 134  3469651   REC_WORD  wordpools/valuecourier_wordpool.txt    40.933334
# 165  4000546   REC_WORD  wordpools/valuecourier_wordpool.txt    16.133333
# 166  4005567   REC_WORD  wordpools/valuecourier_wordpool.txt    16.133333
# 167  4007128   REC_WORD  wordpools/valuecourier_wordpool.txt    16.133333
# 168  4008338   REC_WORD  wordpools/valuecourier_wordpool.txt    16.133333
# 169  4009978   REC_WORD  wordpools/valuecourier_wordpool.txt    16.133333
# 170  4038297   REC_WORD  wordpools/valuecourier_wordpool.txt    16.133333
# 199  4598602   REC_WORD  wordpools/valuecourier_wordpool.txt    17.000000
# 200  4599528   REC_WORD  wordpools/valuecourier_wordpool.txt    17.000000
# 201  4600504   REC_WORD  wordpools/valuecourier_wordpool.txt    17.000000
# 202  4604893   REC_WORD  wordpools/valuecourier_wordpool.txt    17.000000
# 203  4605996   REC_WORD  wordpools/valuecourier_wordpool.txt    17.000000
# 204  4609114   REC_WORD  wordpools/valuecourier_wordpool.txt    17.000000
# 205  4612059   REC_WORD  wordpools/valuecourier_wordpool.txt    17.000000
# 233  5173708   REC_WORD  wordpools/valuecourier_wordpool.txt    34.933334
# 234  5175771   REC_WORD  wordpools/valuecourier_wordpool.txt    34.933334
# 236  5182864   REC_WORD  wordpools/valuecourier_wordpool.txt    34.933334
#
#      compensation                                            eegfile  \
# 91       8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 92       8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 93       8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 94       8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 95       8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 96       8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 126      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 127      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 128      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 129      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 131      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 132      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 134      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 165      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 166      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 167      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 168      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 169      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 170      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 199      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 200      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 201      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 202      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 203      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 204      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 205      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 233      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 234      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 236      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
#
#      eogArtifact    experiment  intruded  intrusion            item  itemno  \
# 91            -1  ValueCourier       NaN        0.0        DOUGHNUT    71.0
# 92            -1  ValueCourier       NaN        0.0       WATER_GUN   232.0
# 93            -1  ValueCourier       NaN        0.0         NAILGUN   138.0
# 94            -1  ValueCourier       NaN        0.0           JEANS   115.0
# 95            -1  ValueCourier       NaN        0.0           SYRUP   212.0
# 96            -1  ValueCourier       NaN        0.0            CAGE    33.0
# 126           -1  ValueCourier       NaN        0.0         DIAMOND    68.0
# 127           -1  ValueCourier       NaN        0.0       PEPPERONI   158.0
# 128           -1  ValueCourier       NaN        0.0         HAMSTER   105.0
# 129           -1  ValueCourier       NaN        0.0     SWEET-N-LOW   210.0
# 131           -1  ValueCourier       NaN        0.0            ROLL   177.0
# 132           -1  ValueCourier       NaN        1.0  PROTEIN_SHAKES   164.0
# 134           -1  ValueCourier       NaN        1.0        VITAMINS   229.0
# 165           -1  ValueCourier       NaN        0.0           CREAM    60.0
# 166           -1  ValueCourier       NaN        0.0           ADVIL     2.0
# 167           -1  ValueCourier       NaN        0.0         ASPIRIN    10.0
# 168           -1  ValueCourier       NaN        0.0           FLOUR    87.0
# 169           -1  ValueCourier       NaN        0.0           FERNS    82.0
# 170           -1  ValueCourier       NaN        0.0            CAPE    38.0
# 199           -1  ValueCourier       NaN        0.0       EYE_DROPS    80.0
# 200           -1  ValueCourier       NaN        0.0            BIRD    21.0
# 201           -1  ValueCourier       NaN        0.0          BAGELS    12.0
# 202           -1  ValueCourier       NaN        0.0       SUNFLOWER   208.0
# 203           -1  ValueCourier       NaN        0.0          RIBBON   175.0
# 204           -1  ValueCourier       NaN        0.0      MOZZARELLA   135.0
# 205           -1  ValueCourier       NaN        0.0      BOARD_GAME    24.0
# 233           -1  ValueCourier       NaN        0.0          WRENCH   234.0
# 234           -1  ValueCourier       NaN        0.0             CDS    40.0
# 236           -1  ValueCourier       NaN        0.0       KICKBOARD   118.0
#
#      itemvalue  montage  msoffset  multiplier  numingroupchosen phase  \
# 91         NaN        0        20    0.846154               4.0     1
# 92         NaN        0        20    0.846154               4.0     1
# 93         NaN        0        20    0.846154               4.0     1
# 94         NaN        0        20    0.846154               4.0     1
# 95         NaN        0        20    0.846154               4.0     1
# 96         NaN        0        20    0.846154               4.0     1
# 126        NaN        0        20    0.846154               4.0     1
# 127        NaN        0        20    0.846154               4.0     1
# 128        NaN        0        20    0.846154               4.0     1
# 129        NaN        0        20    0.846154               4.0     1
# 131        NaN        0        20    0.846154               4.0     1
# 132        NaN        0        20    0.846154               4.0     1
# 134        NaN        0        20    0.846154               4.0     1
# 165        NaN        0        20    0.846154               4.0     1
# 166        NaN        0        20    0.846154               4.0     1
# 167        NaN        0        20    0.846154               4.0     1
# 168        NaN        0        20    0.846154               4.0     1
# 169        NaN        0        20    0.846154               4.0     1
# 170        NaN        0        20    0.846154               4.0     1
# 199        NaN        0        20    0.846154               4.0     1
# 200        NaN        0        20    0.846154               4.0     1
# 201        NaN        0        20    0.846154               4.0     1
# 202        NaN        0        20    0.846154               4.0     1
# 203        NaN        0        20    0.846154               4.0     1
# 204        NaN        0        20    0.846154               4.0     1
# 205        NaN        0        20    0.846154               4.0     1
# 233        NaN        0        20    0.846154               4.0     1
# 234        NaN        0        20    0.846154               4.0     1
# 236        NaN        0        20    0.846154               4.0     1
#
#      playerrotY     presX      presZ  primacybuf protocol  recalled  rectime  \
# 91          NaN -4.765625  10.031250         2.0      ltp       NaN   1175.0
# 92          NaN -4.765625  10.031250         2.0      ltp       NaN   2513.0
# 93          NaN -4.765625  10.031250         2.0      ltp       NaN   4005.0
# 94          NaN -4.765625  10.031250         2.0      ltp       NaN   6345.0
# 95          NaN -4.765625  10.031250         2.0      ltp       NaN   8138.0
# 96          NaN -4.765625  10.031250         2.0      ltp       NaN  24700.0
# 126         NaN -5.082031  10.515625         2.0      ltp       NaN    931.0
# 127         NaN -5.082031  10.515625         2.0      ltp       NaN   6135.0
# 128         NaN -5.082031  10.515625         2.0      ltp       NaN  26428.0
# 129         NaN -5.082031  10.515625         2.0      ltp       NaN  31568.0
# 131         NaN -5.082031  10.515625         2.0      ltp       NaN  51512.0
# 132         NaN -5.082031  10.515625         2.0      ltp       NaN  69049.0
# 134         NaN -5.082031  10.515625         2.0      ltp       NaN  71123.0
# 165         NaN -5.078125   9.765625         2.0      ltp       NaN   1399.0
# 166         NaN -5.078125   9.765625         2.0      ltp       NaN   6420.0
# 167         NaN -5.078125   9.765625         2.0      ltp       NaN   7981.0
# 168         NaN -5.078125   9.765625         2.0      ltp       NaN   9191.0
# 169         NaN -5.078125   9.765625         2.0      ltp       NaN  10831.0
# 170         NaN -5.078125   9.765625         2.0      ltp       NaN  39150.0
# 199         NaN -4.730469  10.023438         2.0      ltp       NaN    936.0
# 200         NaN -4.730469  10.023438         2.0      ltp       NaN   1862.0
# 201         NaN -4.730469  10.023438         2.0      ltp       NaN   2838.0
# 202         NaN -4.730469  10.023438         2.0      ltp       NaN   7227.0
# 203         NaN -4.730469  10.023438         2.0      ltp       NaN   8330.0
# 204         NaN -4.730469  10.023438         2.0      ltp       NaN  11448.0
# 205         NaN -4.730469  10.023438         2.0      ltp       NaN  14393.0
# 233         NaN -4.433594   9.921875         2.0      ltp       NaN   1024.0
# 234         NaN -4.433594   9.921875         2.0      ltp       NaN   3087.0
# 236         NaN -4.433594   9.921875         2.0      ltp       NaN  10180.0
#
#      recencybuf  serialpos  session           store      storeX      storeZ  \
# 91          3.0       14.0        0          bakery  -80.687500  110.125000
# 92          3.0        2.0        0       toy_store  -29.187500  -93.875000
# 93          3.0        5.0        0  hardware_store   -8.867188  131.875000
# 94          3.0        1.0        0  clothing_store   56.718750   77.937500
# 95          3.0        9.0        0            cafe -112.062500  -30.484375
# 96          3.0       12.0        0       pet_store   93.562500   -7.761719
# 126         3.0        3.0        0   jewelry_store  -37.500000   61.000000
# 127         3.0       15.0        0        pizzeria   98.687500   51.812500
# 128         3.0       10.0        0       pet_store   93.562500   -7.761719
# 129         3.0        5.0        0            cafe -112.062500  -30.484375
# 131         3.0       11.0        0          bakery  -80.687500  110.125000
# 132         3.0        6.0        0             gym   93.625000  -63.875000
# 134         3.0        7.0        0        pharmacy  112.375000  -42.781250
# 165         3.0       14.0        0            cafe -112.062500  -30.484375
# 166         3.0        1.0        0         dentist  -14.023438  -19.500000
# 167         3.0        2.0        0        pharmacy  112.375000  -42.781250
# 168         3.0        3.0        0          bakery  -80.687500  110.125000
# 169         3.0        6.0        0         florist  140.750000   60.593750
# 170         3.0        8.0        0     barber_shop   19.484375  173.500000
# 199         3.0        1.0        0        pharmacy  112.375000  -42.781250
# 200         3.0        2.0        0       pet_store   93.562500   -7.761719
# 201         3.0        3.0        0          bakery  -80.687500  110.125000
# 202         3.0        7.0        0         florist  140.750000   60.593750
# 203         3.0        9.0        0      craft_shop    2.859375   57.812500
# 204         3.0       15.0        0        pizzeria   98.687500   51.812500
# 205         3.0        6.0        0       toy_store  -29.187500  -93.875000
# 233         3.0       13.0        0  hardware_store   -8.867188  131.875000
# 234         3.0        4.0        0     music_store -107.937500  -87.000000
# 236         3.0       14.0        0             gym   93.625000  -63.875000
#
#     storepointtype subject  trial  valuerecall
# 91        Temporal  LTP606      0         15.0
# 92        Temporal  LTP606      0         15.0
# 93        Temporal  LTP606      0         15.0
# 94        Temporal  LTP606      0         15.0
# 95        Temporal  LTP606      0         15.0
# 96        Temporal  LTP606      0         15.0
# 126       Temporal  LTP606      1         40.0
# 127       Temporal  LTP606      1         40.0
# 128       Temporal  LTP606      1         40.0
# 129       Temporal  LTP606      1         40.0
# 131       Temporal  LTP606      1         40.0
# 132       Temporal  LTP606      1         40.0
# 134       Temporal  LTP606      1         40.0
# 165         random  LTP606      2         14.0
# 166         random  LTP606      2         14.0
# 167         random  LTP606      2         14.0
# 168         random  LTP606      2         14.0
# 169         random  LTP606      2         14.0
# 170         random  LTP606      2         14.0
# 199         random  LTP606      3         15.0
# 200         random  LTP606      3         15.0
# 201         random  LTP606      3         15.0
# 202         random  LTP606      3         15.0
# 203         random  LTP606      3         15.0
# 204         random  LTP606      3         15.0
# 205         random  LTP606      3         15.0
# 233       Temporal  LTP606      4         22.0
# 234       Temporal  LTP606      4         22.0
# 236       Temporal  LTP606      4         22.0

# %%
# we can also set the datatype to "eeg" and load it this way
# by setting it to "eeg", we avoid having to remake a BIDSPath object for both the EEG and behavioral data
bids_path = BIDSPath(
    subject=subject,
    session=str(session),
    task=task,
    datatype="eeg",
    root=bids_root,
)

events_path = os.path.join(bids_path.directory, bids_path.basename + "_events.tsv")
evs_bids = pd.read_csv(events_path, sep="\t")
evs_bids[:10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 12
#       3 bids_path = BIDSPath(
#       4     subject=subject,
#       5     session=str(session),
#    (...)
#       8     root=bids_root,
#       9 )
#      11 events_path = os.path.join(bids_path.directory, bids_path.basename + "_events.tsv")
# ---> 12 evs_bids = pd.read_csv(events_path, sep="\t")
#      13 evs_bids[:10]
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP063/ses-0/eeg/sub-LTP063_ses-0_task-ltpfr_events.tsv'

# %% [markdown]
# ## Differences Between CML and OpenBIDS Events
#
# The event dataframes loaded via OpenBIDS and CMLReader are identical in content, with the only differences being a small number of additional or renamed columns in the OpenBIDS version that conform to OpenBIDS formatting standards.

# %%
evs_cml.columns

# %%
evs_bids.columns

# %% [markdown]
# ### Column differences
# | CMLReader column | OpenBIDS column | Notes |
# |------------------|-----------------|-------|
# | `eegoffset` | `sample` | Same information; renamed to match BIDS conventions |
# | `type` | `trial_type` | Renamed for BIDS compliance |
# | `mstime` | `mstime` | In BIDS, `mstime` is typically shifted so that `mstime[0] = 0` |
# | *(derived)* | `onset` | Computed as `sample / sample_frequency` |
# | *(not present)* | `duration` | Not used / not applicable |
# | *(not present)* | `stim_file` | Empty string placeholder required by BIDS |

# %% [markdown]
# ## Loading Raw EEG
#
# Here's how we load the whole raw EEG file without creating epochs.

# %% [markdown]
# ### CMLReader

# %%
# use reader from events
eeg_cml = cmlreader.load_eeg().to_ptsa()

# %% [markdown]
# ### OpenBIDS

# %%
# use BIDSPath with datatype set to "eeg"
bids_path = BIDSPath(
            subject=subject,
            session=str(session),
            task=task,
            datatype="eeg",
            root=bids_root,
        )

# load the header from the bids file
raw = read_raw_bids(
    bids_path,
    verbose=True,
)

# %%
# ptsa is just a wrapper for XArray, so we can just create an XArray object using the data from raw
eeg_bids = xr.DataArray(
    raw.get_data()[None, :, :],                # load the raw eeg data                  
    dims=("event", "channel", "time"),      
    coords={
        "event": [0],                          # singleton event index
        "channel": raw.ch_names,
        "time": raw.times  ,
        "samplerate": raw.info["sfreq"],          
    },
    name="eeg",
)
eeg_bids

# %% [markdown]
# ## Loading Epoched EEG
#
# Here's how to load Epoched EEG data. First let's set the constants.

# %%
# constants
REL_START, REL_STOP = 200, 3000
BUFFER_MS = 1000
WIDTH = 6

FREQS = np.logspace(np.log10(2), np.log10(100), 46)
NOTCH_BAND = (58., 62.)
BATCH_EVENTS = 64

# %% [markdown]
# ### CMLReader
#
# It is easy to load the eeg data using the load_eeg method of the Reader object.

# %%
# many of our analyses use the clean function, but to get the same data as the BIDS loader, we will forego it
# epochs_cml = reader.load_eeg(
#     word_evs_cml, rel_start=-BUFFER_MS, rel_stop=REL_STOP + BUFFER_MS, clean='LCF'
# ).to_ptsa()

# filter events
word_evs_cml = evs_cml[evs_cml["type"] == "WORD"]

epochs_cml = cmlreader.load_eeg(
    word_evs_cml, rel_start=-BUFFER_MS, rel_stop=REL_STOP + BUFFER_MS
).to_ptsa()
epochs_cml

# %% [markdown]
# ### OpenBIDS
#
# We can load epochs for OpenBIDS using the MNE Epochs object then converting to ptsa.
#
# REMINDER: MNE Epochs uses seconds so we must divide by 1000 if the constants were in seconds.

# %%
# get BIDSPath
bids_path = BIDSPath(
    subject=subject,
    session=str(session),
    task=task,
    datatype="eeg",
    root=bids_root,
)

# and load raw data
raw = read_raw_bids(bids_path)

# set non-EEG channels
raw.set_channel_types({
    "EXG1": "eog", "EXG2": "eog", "EXG3": "eog", "EXG4": "eog",
    "EXG5": "misc", "EXG6": "misc", "EXG7": "misc", "EXG8": "misc",
})

# %% [markdown]
# ### Filtering Events for Loading
#
# In order to select the events that we will epoch over, we must get the string representation from the events from the raw data's header using the events_from_annotations function. The function returns "events" which maps the sample to the event index and "event_id" which maps each event name to its index.

# %%
# get events from raw data's header
events, event_id = mne.events_from_annotations(raw)

# %% [markdown]
# To filter the events, we select only the event_ids we are interested in.

# %%
# filter word events and return the index of the WORD event
word_event_id = {k: v for k, v in event_id.items() if k == "WORD"}
word_event_id

# %%
tmin = (-BUFFER_MS / 1000)
tmax = ((REL_STOP /1000 + BUFFER_MS / 1000))

# load into MNE Epochs object
epochs_mne = mne.Epochs(
    raw,
    events=events,                      # we can now load the events here
    event_id=word_event_id,             # we cna also load the filtered events here
    tmin=tmin,
    tmax=tmax,
    baseline=(None, 0), # None goes to start, 0 is onset of stimuli
    preload=True,
    event_repeated="merge",
)
epochs_mne

# %%
# convert to ptsa
epochs_bids = TimeSeries.from_mne_epochs(epochs_mne, word_evs_bids)
epochs_bids

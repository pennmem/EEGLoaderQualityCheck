# %% [markdown]
# # CML vs BIDS Comparison
#
# Using `bids_validation` package with `BIDSReader`.

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

import os
import numpy as np
import pandas as pd
import cmlreaders as cml
import matplotlib.pyplot as plt
# %matplotlib inline

from eeg_validation import (
    EventsPipeline,
    RawSignalPipeline,
    EpochedPipeline,
    MontagePipeline,
)
from eeg_validation.io import load_and_concat
from eeg_validation.plotting import plot_comparison_results

pd.options.display.max_rows = 100
pd.options.display.max_columns = 50
import sys
sys.path.append("/home1/zrentala/bidsreader")
from bidsreader import BIDSReader

# %% [markdown]
# ## 1. Configuration

# %%
# ---- Shared settings ----
REL_START = 200      # ms
REL_STOP  = 500     # ms
BUFFER_MS = 500     # ms
tmin = -BUFFER_MS
tmax = REL_STOP + BUFFER_MS

MAX_SUBJECTS = 10
SUBJECTS_TO_EXCLUDE = {"LTP001", "LTP9992", "LTP9993"}

# Set to True to skip sessions whose output CSVs already exist
SKIP_IF_EXISTS = True

# %% [markdown]
# ---
# ## 2. Scalp / LTP Comparisons

# %% [markdown]
# ### 2a. Select subjects & sessions

# %%
ltp_experiments = ["ValueCourier"]
ltp_bids_root   = "/data/LTP_BIDS/"
ltp_out_path    = "ltp_results/"

df = cml.get_data_index()
df_exp = df[df["experiment"].isin(ltp_experiments)].copy()
df_exp = df_exp[~df_exp["subject"].isin(SUBJECTS_TO_EXCLUDE)]

dfs = []
for exp in ltp_experiments:
    df_this = df_exp[df_exp["experiment"] == exp]
    subjects = df_this["subject"].drop_duplicates().sort_values().head(MAX_SUBJECTS)
    dfs.append(df_this[df_this["subject"].isin(subjects)])

df_ltp = pd.concat(dfs, ignore_index=True)
print(f"LTP jobs: {len(df_ltp)} sessions across {df_ltp['subject'].nunique()} subjects")
df_ltp[["subject", "experiment", "session"]].head(20)
# Out:
# LTP jobs: 28 sessions across 8 subjects
#    subject    experiment  session
# 0   LTP606  ValueCourier        0
# 1   LTP606  ValueCourier        1
# 2   LTP606  ValueCourier        2
# 3   LTP606  ValueCourier        3
# 4   LTP606  ValueCourier        4
# 5   LTP606  ValueCourier        5
# 6   LTP607  ValueCourier        0
# 7   LTP607  ValueCourier        1
# 8   LTP607  ValueCourier        2
# 9   LTP607  ValueCourier        3
# 10  LTP607  ValueCourier        4
# 11  LTP607  ValueCourier        5
# 12  LTP609  ValueCourier        0
# 13  LTP609  ValueCourier        1
# 14  LTP609  ValueCourier        2
# 15  LTP609  ValueCourier        3
# 16  LTP609  ValueCourier        4
# 17  LTP609  ValueCourier        5
# 18  LTP610  ValueCourier        0
# 19  LTP610  ValueCourier        1

# %% [markdown]
# ### 2b. Run Raw + Epoched EEG comparisons

# %%
for _, row in df_ltp.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])
    bids_root = ltp_bids_root

    # --- Raw (scalp: no acquisition) ---
    try:
        result = RawSignalPipeline(
            sub, exp, sess, bids_root, ltp_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
        ).run()
        tag = "SKIP" if isinstance(result, dict) and result.get("skipped") else "DONE"
        print(f"[{tag}] Raw  | {sub} | {exp} | {sess}")
    except Exception as e:
        print(f"[FAIL] Raw  | {sub} | {exp} | {sess}: {e}")

    # --- Epoched (scalp: no acquisition) ---
    try:
        result = EpochedPipeline(
            sub, exp, sess, bids_root, ltp_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
            tmin=tmin, tmax=tmax, verbose=True,
        ).run()
        tag = "SKIP" if isinstance(result, dict) and result.get("skipped") else "DONE"
        print(f"[{tag}] Epoch | {sub} | {exp} | {sess}")
    except Exception as e:
        print(f"[FAIL] Epoch | {sub} | {exp} | {sess}: {e}")
# Out:
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Extracting EDF parameters from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_eeg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_events.tsv.
# Reading channel info from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_space-CapTrak_electrodes.tsv.
# [DONE] Raw  | LTP606 | ValueCourier | 0
#
# ============================================================
# [EpochedPipeline] Starting pipeline for LTP606_ValueCourier_0
# ============================================================
#   Output directory: ltp_results/
#   Loading CML events...
#   CML events loaded: 242 rows
#   Loading BIDS events (event_type=eeg)...
#   BIDS events loaded: 242 rows
#   Event types to process: ['FINAL_COMPENSATION', 'POINTER_ON', 'PRACTICE_DELIVERY_END', 'PRACTICE_DELIVERY_START', 'PRACTICE_VALUE_RECALL', 'PRACTICE_WORD', 'REC_START', 'REC_STOP', 'REC_WORD', 'REC_WORD_VV', 'SESS_END', 'SESS_START', 'TL_END', 'TL_START', 'TRIAL_END', 'TRIAL_START', 'VALUE_RECALL', 'VIDEO_START', 'VIDEO_STOP', 'WORD', 'store mappings']
#   Epoch window: tmin=-500 ms, tmax=1000 ms
#   Acquisition streams: ['eeg']
#
#   === Acquisition: eeg ===
#   Types with CML data: ['FINAL_COMPENSATION', 'POINTER_ON', 'PRACTICE_DELIVERY_END', 'PRACTICE_DELIVERY_START', 'PRACTICE_VALUE_RECALL', 'PRACTICE_WORD', 'REC_START', 'REC_STOP', 'REC_WORD', 'REC_WORD_VV', 'SESS_END', 'SESS_START', 'TL_END', 'TL_START', 'TRIAL_END', 'TRIAL_START', 'VALUE_RECALL', 'VIDEO_START', 'VIDEO_STOP', 'WORD', 'store mappings']
#   Types with BIDS data: ['FINAL_COMPENSATION', 'POINTER_ON', 'PRACTICE_DELIVERY_END', 'PRACTICE_DELIVERY_START', 'PRACTICE_VALUE_RECALL', 'PRACTICE_WORD', 'REC_START', 'REC_STOP', 'REC_WORD', 'REC_WORD_VV', 'SESS_END', 'SESS_START', 'TL_END', 'TL_START', 'TRIAL_END', 'TRIAL_START', 'VALUE_RECALL', 'VIDEO_START', 'VIDEO_STOP', 'WORD', 'store mappings']
#   Bulk CML load: 240 events, types=['FINAL_COMPENSATION', 'POINTER_ON', 'PRACTICE_DELIVERY_END', 'PRACTICE_DELIVERY_START', 'PRACTICE_VALUE_RECALL', 'PRACTICE_WORD', 'REC_START', 'REC_STOP', 'REC_WORD', 'REC_WORD_VV', 'SESS_END', 'SESS_START', 'TL_END', 'TL_START', 'TRIAL_END', 'TRIAL_START', 'VALUE_RECALL', 'VIDEO_START', 'VIDEO_STOP', 'WORD', 'store mappings']
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 240 events and 3073 original time points ...
# 0 bad epochs dropped
#   CML bulk EEG shape: (240, 137, 3073)
#   Bulk BIDS load: 240 events, types=['FINAL_COMPENSATION', 'POINTER_ON', 'PRACTICE_DELIVERY_END', 'PRACTICE_DELIVERY_START', 'PRACTICE_VALUE_RECALL', 'PRACTICE_WORD', 'REC_START', 'REC_STOP', 'REC_WORD', 'REC_WORD_VV', 'SESS_END', 'SESS_START', 'TL_END', 'TL_START', 'TRIAL_END', 'TRIAL_START', 'VALUE_RECALL', 'VIDEO_START', 'VIDEO_STOP', 'WORD', 'store mappings']
# Extracting EDF parameters from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_eeg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_events.tsv.
# Reading channel info from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_space-CapTrak_electrodes.tsv.
# Used Annotations descriptions: ['FINAL_COMPENSATION', 'POINTER_ON', 'PRACTICE_DELIVERY_END', 'PRACTICE_DELIVERY_START', 'PRACTICE_VALUE_RECALL', 'PRACTICE_WORD', 'REC_START', 'REC_STOP', 'REC_WORD', 'REC_WORD_VV', 'SESS_END', 'SESS_START', 'TL_END', 'TL_START', 'TRIAL_END', 'TRIAL_START', 'VALUE_RECALL', 'VIDEO_START', 'VIDEO_STOP', 'WORD', 'store mappings']
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 240 events and 3073 original time points ...
# Exception ignored in: <function BaseRaw.__del__ at 0x2b583989d1c0>
# Traceback (most recent call last):
#   File "/usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne/io/base.py", line 736, in __del__
#     def __del__(self):  # noqa: D105
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 22
#      16 # --- Epoched (scalp: no acquisition) ---
#      17 try:
#      18     result = EpochedPipeline(
#      19         sub, exp, sess, bids_root, ltp_out_path,
#      20         skip_if_exists=SKIP_IF_EXISTS,
#      21         tmin=tmin, tmax=tmax, verbose=True,
# ---> 22     ).run()
#      23     tag = "SKIP" if result.get("skipped") else "DONE"
#      24     print(f"[{tag}] Epoch | {sub} | {exp} | {sess}")
#
# File ~/eeg-validation/eeg_validation/pipelines/base.py:73, in run(self)
#      69         return None
#      70     return self._ACQ_MAP[self.acquisition]["bids"]
#      72 @property
# ---> 73 def acq_label(self) -> str:
#      74     """Short label for file naming — 'contacts', 'pairs', or 'eeg'."""
#      75     return self.acquisition or "eeg"
#
# File ~/eeg-validation/eeg_validation/pipelines/epoched.py:308, in _run(self)
#     306     self._vprint(f"      Skipped: no BIDS events")
#     307     status.append((acq, etype, "skip", "no_bids_events"))
# --> 308     continue
#     310 if eeg_cml_all is None:
#     311     self._vprint(f"      Skipped: CML bulk load entirely failed")
#
# File ~/eeg-validation/eeg_validation/pipelines/epoched.py:161, in _bulk_load_bids(self, bids_events_by_type, types_to_run, bids_acq, status, acq_tag)
#     159 if len(picks) == 0:
#     160     picks = np.arange(len(epochs_all.ch_names))
# --> 161 epochs_all = epochs_all.pick(picks)
#     163 eeg_all = epochs_to_ptsa(epochs_all, evs_combined)
#     164 eeg_all = convert_unit(eeg_all, "uV", copy=False)
#
# File ~/bidsreader/bidsreader/_errorwrap.py:21, in public_api.<locals>.wrapper(*args, **kwargs)
#      18 @wraps(func)
#      19 def wrapper(*args, **kwargs):
#      20     try:
# ---> 21         return func(*args, **kwargs)
#      23     # If it's already one of yours, don't touch it.
#      24     except BIDSReaderError:
#
# File ~/bidsreader/bidsreader/bidsreader.py:378, in BIDSReader.load_epochs(self, tmin, tmax, events, baseline, acquisition, event_repeated, channels, preload)
#     375     event_id = all_event_id
#     377 picks = list(channels) if channels is not None else None
# --> 378 return mne.Epochs(
#     379     raw,
#     380     events=events_raw,
#     381     event_id=event_id,
#     382     tmin=tmin,
#     383     tmax=tmax,
#     384     baseline=baseline,
#     385     preload=preload,
#     386     event_repeated=event_repeated,
#     387     picks=picks,
#     388 )
#
# File <decorator-gen-288>:12, in __init__(self, raw, events, event_id, tmin, tmax, baseline, picks, preload, reject, flat, proj, decim, reject_tmin, reject_tmax, detrend, on_missing, reject_by_annotation, metadata, event_repeated, verbose)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne/epochs.py:3084, in Epochs.__init__(self, raw, events, event_id, tmin, tmax, baseline, picks, preload, reject, flat, proj, decim, reject_tmin, reject_tmax, detrend, on_missing, reject_by_annotation, metadata, event_repeated, verbose)
#    3081 raw_sfreq = raw.info["sfreq"]
#    3083 # call BaseEpochs constructor
# -> 3084 super(Epochs, self).__init__(
#    3085     info,
#    3086     None,
#    3087     events,
#    3088     event_id,
#    3089     tmin,
#    3090     tmax,
#    3091     metadata=metadata,
#    3092     baseline=baseline,
#    3093     raw=raw,
#    3094     picks=picks,
#    3095     reject=reject,
#    3096     flat=flat,
#    3097     decim=decim,
#    3098     reject_tmin=reject_tmin,
#    3099     reject_tmax=reject_tmax,
#    3100     detrend=detrend,
#    3101     proj=proj,
#    3102     on_missing=on_missing,
#    3103     preload_at_end=preload,
#    3104     event_repeated=event_repeated,
#    3105     verbose=verbose,
#    3106     raw_sfreq=raw_sfreq,
#    3107     annotations=raw.annotations,
#    3108 )
#
# File <decorator-gen-274>:12, in __init__(self, info, data, events, event_id, tmin, tmax, baseline, raw, picks, reject, flat, decim, reject_tmin, reject_tmax, detrend, proj, on_missing, preload_at_end, selection, drop_log, filename, metadata, event_repeated, raw_sfreq, annotations, verbose)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne/epochs.py:684, in BaseEpochs.__init__(***failed resolving arguments***)
#     682     assert self._data is None
#     683     assert self.preload is False
# --> 684     self.load_data()  # this will do the projection
#     685 elif proj is True and self._projector is not None and data is not None:
#     686     # let's make sure we project if data was provided and proj
#     687     # requested
#     688     # we could do this with np.einsum, but iteration should be
#     689     # more memory safe in most instances
#     690     for ii, epoch in enumerate(self._data):
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne/epochs.py:740, in BaseEpochs.load_data(self)
#     738 if self.preload:
#     739     return self
# --> 740 self._data = self._get_data()
#     741 self.preload = True
#     742 self._do_baseline = False
#
# File <decorator-gen-280>:12, in _get_data(self, out, picks, item, units, tmin, tmax, verbose)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne/epochs.py:1711, in BaseEpochs._get_data(self, out, picks, item, units, tmin, tmax, verbose)
#    1709         epoch = self._data[idx]
#    1710 else:  # from disk
# -> 1711     epoch_noproj = self._get_epoch_from_raw(idx)
#    1712     epoch_noproj = self._detrend_offset_decim(
#    1713         epoch_noproj, detrend_picks
#    1714     )
#    1715     epoch = self._project_epoch(epoch_noproj)
#
# File <decorator-gen-289>:12, in _get_epoch_from_raw(self, idx, verbose)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne/epochs.py:3151, in Epochs._get_epoch_from_raw(self, idx, verbose)
#    3148 reject_stop = stop - diff
#    3150 logger.debug("    Getting epoch for %d-%d" % (start, stop))
# -> 3151 data = self._raw._check_bad_segment(
#    3152     start,
#    3153     stop,
#    3154     self.picks,
#    3155     reject_start,
#    3156     reject_stop,
#    3157     self.reject_by_annotation,
#    3158 )
#    3159 return data
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne/io/base.py:551, in BaseRaw._check_bad_segment(self, start, stop, picks, reject_start, reject_stop, reject_by_annotation)
#     549         if descr.lower().startswith("bad"):
#     550             return descr
# --> 551 return self._getitem((picks, slice(start, stop)), return_times=False)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne/io/base.py:841, in BaseRaw._getitem(self, item, return_times)
#     839     data = self._data[sel, start:stop]
#     840 else:
# --> 841     data = self._read_segment(start=start, stop=stop, sel=sel)
#     843 if return_times:
#     844     # Rather than compute the entire thing just compute the subset
#     845     # times = self.times[start:stop]
#     846     # stop can be None here so don't use it directly
#     847     times = np.arange(start, start + data.shape[1], dtype=float)
#
# File <decorator-gen-233>:12, in _read_segment(self, start, stop, sel, data_buffer, verbose)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne/io/base.py:408, in BaseRaw._read_segment(***failed resolving arguments***)
#     405     data = _allocate_data(data_buffer, data_shape, dtype)
#     407 # deal with having multiple files accessed by the raw object
# --> 408 cumul_lens = np.concatenate(([0], np.array(self._raw_lengths, dtype="int")))
#     409 cumul_lens = np.cumsum(cumul_lens)
#     410 files_used = np.logical_and(
#     411     np.less(start, cumul_lens[1:]), np.greater_equal(stop - 1, cumul_lens[:-1])
#     412 )
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2c. Run Behavioral Events comparison

# %%
for _, row in df_ltp.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])

    try:
        result = EventsPipeline(
            sub, exp, sess, ltp_bids_root, ltp_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
        ).run()
        tag = "SKIP" if isinstance(result, dict) and result.get("skipped") else "DONE"
        print(f"[{tag}] Events | {sub} | {exp} | {sess}: {result.get('reason')}")
    except Exception as e:
        print(f"[FAIL] Events | {sub} | {exp} | {sess}: {e}")
# Out:
# 0         23440
# 1         31922
# 2        468068
# 3        646089
# 4        646183
#          ...
# 237    10769845
# 238    10769847
# 239    10774076
# 240    10774082
# 241    10774084
# Name: sample, Length: 242, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 0: None
# 0         26913
# 1         35692
# 2         40775
# 3         44050
# 4         46917
#          ...
# 322    11185152
# 323    11185154
# 324    11188636
# 325    11188640
# 326    11188642
# Name: sample, Length: 327, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 1: None
# 0          1870
# 1          4027
# 2          5323
# 3          5831
# 4          6755
#          ...
# 304    10513236
# 305    10513236
# 306    10518356
# 307    10518362
# 308    10518364
# Name: sample, Length: 309, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 2: None
# 0        17126
# 1        19110
# 2        20114
# 3        20931
# 4        21477
#         ...
# 316    9440931
# 317    9440931
# 318    9444682
# 319    9444687
# 320    9444687
# Name: sample, Length: 321, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 3: None
# 0         8640
# 1         9910
# 2        10283
# 3        10658
# 4        10961
#         ...
# 327    9685087
# 328    9685087
# 329    9688432
# 330    9688438
# 331    9688438
# Name: sample, Length: 332, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 4: None
# 0        54228
# 1        56177
# 2        56654
# 3        57166
# 4        57574
#         ...
# 180    5428009
# 181    5460438
# 182    5575424
# 183    5575426
# 184    5578938
# Name: sample, Length: 185, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 5: None
# 0         31959
# 1         38287
# 2        474408
# 3        695343
# 4        695433
#          ...
# 255    11094864
# 256    11094866
# 257    11101112
# 258    11101118
# 259    11101120
# Name: sample, Length: 260, dtype: int64
# [DONE] Events | LTP607 | ValueCourier | 0: None
# 0         20907
# 1         33130
# 2         34939
# 3         36606
# 4         37359
#          ...
# 356    10828051
# 357    10828051
# 358    10832524
# 359    10832530
# 360    10832530
# Name: sample, Length: 361, dtype: int64
# [DONE] Events | LTP607 | ValueCourier | 1: None
# [SKIP] Events | LTP607 | ValueCourier | 2: bids_events_not_found
# [SKIP] Events | LTP607 | ValueCourier | 3: bids_events_not_found
# 0        13115
# 1        17248
# 2        18032
# 3        18409
# 4        18714
#         ...
# 356    9922591
# 357    9922591
# 358    9926179
# 359    9926183
# 360    9926185
# Name: sample, Length: 361, dtype: int64
# [DONE] Events | LTP607 | ValueCourier | 4: None
# 0        16455
# 1        22639
# 2        23047
# 3        23387
# 4        23966
#         ...
# 366    9505791
# 367    9505791
# 368    9509135
# 369    9509141
# 370    9509143
# Name: sample, Length: 371, dtype: int64
# [DONE] Events | LTP607 | ValueCourier | 5: None
# 0          6636
# 1         18768
# 2        454867
# 3        674643
# 4        674737
#          ...
# 233    11269067
# 234    11269067
# 235    11274901
# 236    11274905
# 237    11274908
# Name: sample, Length: 238, dtype: int64
# [DONE] Events | LTP609 | ValueCourier | 0: None
# [SKIP] Events | LTP609 | ValueCourier | 1: bids_events_not_found
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 329   -1
# 330   -1
# 331   -1
# 332   -1
# 333   -1
# Name: sample, Length: 334, dtype: int64
# [DONE] Events | LTP609 | ValueCourier | 2: None
# 0        14704
# 1        31300
# 2        33856
# 3        35222
# 4        35732
#         ...
# 335    9968318
# 336    9968318
# 337    9973440
# 338    9973448
# 339    9973448
# Name: sample, Length: 340, dtype: int64
# [DONE] Events | LTP609 | ValueCourier | 3: None
# 0        19839
# 1        26177
# 2        26685
# 3        27164
# 4        27571
#         ...
# 359    9736392
# 360    9736394
# 361    9740762
# 362    9740764
# 363    9740764
# Name: sample, Length: 364, dtype: int64
# [DONE] Events | LTP609 | ValueCourier | 4: None
# 0         21267
# 1         27009
# 2         27553
# 3         28098
# 4         28608
#          ...
# 356    10110489
# 357    10110489
# 358    10115508
# 359    10115514
# 360    10115517
# Name: sample, Length: 361, dtype: int64
# [DONE] Events | LTP609 | ValueCourier | 5: None
# 0         31159
# 1        134684
# 2        570676
# 3        670950
# 4        671040
#          ...
# 262    12023784
# 263    12023784
# 264    12028773
# 265    12028777
# 266    12028779
# Name: sample, Length: 267, dtype: int64
# [DONE] Events | LTP610 | ValueCourier | 0: None
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 369   -1
# 370   -1
# 371   -1
# 372   -1
# 373   -1
# Name: sample, Length: 374, dtype: int64
# [DONE] Events | LTP610 | ValueCourier | 1: None
# 0         22543
# 1         49960
# 2         51832
# 3         52956
# 4         54017
#          ...
# 333    12531767
# 334    12531767
# 335    12536237
# 336    12536244
# 337    12536244
# Name: sample, Length: 338, dtype: int64
# [DONE] Events | LTP610 | ValueCourier | 2: None
# 0         20241
# 1         25948
# 2         26763
# 3         27511
# 4         28060
#          ...
# 347    12283290
# 348    12283292
# 349    12306946
# 350    12306950
# 351    12306952
# Name: sample, Length: 352, dtype: int64
# [DONE] Events | LTP610 | ValueCourier | 3: None
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 339   -1
# 340   -1
# 341   -1
# 342   -1
# 343   -1
# Name: sample, Length: 344, dtype: int64
# [DONE] Events | LTP610 | ValueCourier | 4: None
# 0         19340
# 1         27843
# 2         29242
# 3         29924
# 4         30538
#          ...
# 345    11502761
# 346    11502761
# 347    11507196
# 348    11507203
# 349    11507203
# Name: sample, Length: 350, dtype: int64
# [DONE] Events | LTP610 | ValueCourier | 5: None
# 0         37359
# 1         61094
# 2        497438
# 3        580651
# 4        580741
#          ...
# 281    12462454
# 282    12462454
# 283    12468425
# 284    12468432
# 285    12468432
# Name: sample, Length: 286, dtype: int64
# [DONE] Events | LTP612 | ValueCourier | 0: None
# 0         15449
# 1         20760
# 2        457281
# 3        525235
# 4        525332
#          ...
# 239    15061402
# 240    15061402
# 241    15071984
# 242    15071990
# 243    15071990
# Name: sample, Length: 244, dtype: int64
# [DONE] Events | LTP613 | ValueCourier | 0: None
# 0         15534
# 1         23158
# 2        459471
# 3        601244
# 4        601337
#          ...
# 244    13677280
# 245    13677280
# 246    13684689
# 247    13684693
# 248    13684695
# Name: sample, Length: 249, dtype: int64
# [DONE] Events | LTP614 | ValueCourier | 0: None
# [SKIP] Events | LTP9996 | ValueCourier | 0: bids_events_not_found

# %% [markdown]
# ### 2d. Aggregate LTP results & plot

# %%
ltp_final = "ltp_final/"
os.makedirs(ltp_final, exist_ok=True)

FILE_CATEGORIES = [
    "df_raw", "df_raw_summary", "df_raw_time",
    "df_behavior_summary",
    "df_epoch", "df_epoch_summary", "df_epoch_time",
]

ltp_dfs = {}
for cat in FILE_CATEGORIES:
    files = [
        os.path.join(dp, f)
        for dp, _, fns in os.walk(ltp_out_path)
        for f in fns
        if f.endswith(".csv") and f.startswith(cat + "_")
    ]
    if not files:
        print(f"Skipping {cat} (no files)")
        continue
    df_all = load_and_concat(files)
    ltp_dfs[cat] = df_all
    outfile = os.path.join(ltp_final, f"{cat}_all.csv")
    df_all.to_csv(outfile, index=False)
    print(f"{cat}: {len(files)} files -> {outfile}")
# Out:
# df_raw: 63 files -> ltp_final/df_raw_all.csv
# df_raw_summary: 21 files -> ltp_final/df_raw_summary_all.csv
# df_raw_time: 21 files -> ltp_final/df_raw_time_all.csv
# df_behavior_summary: 24 files -> ltp_final/df_behavior_summary_all.csv
# Warning: skipping ltp_results/df_epoch_LTP609_ValueCourier_2_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_summary_LTP609_ValueCourier_2_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_time_LTP609_ValueCourier_2_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_LTP610_ValueCourier_1_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_summary_LTP610_ValueCourier_1_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_time_LTP610_ValueCourier_1_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_LTP610_ValueCourier_4_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_summary_LTP610_ValueCourier_4_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_time_LTP610_ValueCourier_4_eeg.csv: No columns to parse from file
# Removed 31409 duplicate rows
# df_epoch: 99 files -> ltp_final/df_epoch_all.csv
# Warning: skipping ltp_results/df_epoch_summary_LTP609_ValueCourier_2_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_summary_LTP610_ValueCourier_1_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_summary_LTP610_ValueCourier_4_eeg.csv: No columns to parse from file
# Removed 21 duplicate rows
# df_epoch_summary: 25 files -> ltp_final/df_epoch_summary_all.csv
# Warning: skipping ltp_results/df_epoch_time_LTP609_ValueCourier_2_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_time_LTP610_ValueCourier_1_eeg.csv: No columns to parse from file
# Warning: skipping ltp_results/df_epoch_time_LTP610_ValueCourier_4_eeg.csv: No columns to parse from file
# df_epoch_time: 24 files -> ltp_final/df_epoch_time_all.csv

# %%
# --- Raw signal plots ---
if "df_raw_summary" in ltp_dfs:
    plot_comparison_results(ltp_dfs["df_raw_summary"], "mean_abs_diff", "std_diff", col_label="Mean Abs Signal Diff")
    plot_comparison_results(ltp_dfs["df_raw_summary"], "mse", col_label="MSE Raw Signal")
    plot_comparison_results(ltp_dfs["df_raw_summary"], "n_exact_diff_channels")
    plot_comparison_results(ltp_dfs["df_raw_summary"], "n_close_diff_channels")

# --- Time coord plots ---
if "df_raw_time" in ltp_dfs:
    plot_comparison_results(ltp_dfs["df_raw_time"], "mean_abs_time_diff", "std_time_diff", col_label="Mean Abs Time Diff")
    plot_comparison_results(ltp_dfs["df_raw_time"], "mse_time", col_label="MSE Time")

# --- Behavioral plots ---
if "df_behavior_summary" in ltp_dfs:
    plot_comparison_results(ltp_dfs["df_behavior_summary"], "n_differing_columns")

# %% [markdown]
# ---
# ## 3. iEEG / RAM Comparisons

# %% [markdown]
# ### 3a. Select subjects & sessions

# %%
ram_experiments = ["FR1"]
ram_bids_root   = "/data/LTP_BIDS/FR1"
ram_out_path    = "ram_results_unit_convert_round/"

ram_subjects_to_include = [
    'R1060M', 'R1061T', 'R1065J', 'R1066P', 'R1092J',
    'R1108J', 'R1111M', 'R1207J', 'R1226D', 'R1230J',
    'R1236J', 'R1243T', 'R1247P', 'R1292E', 'R1308T',
    'R1310J', 'R1328E', 'R1332M', 'R1334T', 'R1337E',
    'R1341T', 'R1354E', 'R1395M', 'R1542J',
]

df = cml.get_data_index()
df_exp = df[df["experiment"].isin(ram_experiments)].copy()
df_exp = df_exp[~df_exp["subject"].isin(SUBJECTS_TO_EXCLUDE)]
df_exp = df_exp[df_exp["subject"].isin(ram_subjects_to_include)]

dfs = []
for exp in ram_experiments:
    df_this = df_exp[df_exp["experiment"] == exp]
    subjects = df_this["subject"].drop_duplicates().sort_values().head(MAX_SUBJECTS)
    dfs.append(df_this[df_this["subject"].isin(subjects)])

df_ram = pd.concat(dfs, ignore_index=True)
print(f"RAM jobs: {len(df_ram)} sessions across {df_ram['subject'].nunique()} subjects")
df_ram[["subject", "experiment", "session", "localization", "montage"]].head(20)
# Out:
# RAM jobs: 39 sessions across 10 subjects
#    subject experiment  session  localization  montage
# 0   R1060M        FR1        0             0        0
# 1   R1060M        FR1        1             0        0
# 2   R1060M        FR1        2             0        0
# 3   R1060M        FR1        3             0        0
# 4   R1061T        FR1        0             0        0
# 5   R1061T        FR1        1             0        0
# 6   R1061T        FR1        2             0        0
# 7   R1061T        FR1        3             0        0
# 8   R1065J        FR1        0             0        0
# 9   R1065J        FR1        1             0        0
# 10  R1065J        FR1        2             0        0
# 11  R1065J        FR1        3             0        0
# 12  R1065J        FR1        4             0        0
# 13  R1065J        FR1        5             0        0
# 14  R1066P        FR1        0             0        0
# 15  R1066P        FR1        1             0        0
# 16  R1066P        FR1        2             0        0
# 17  R1066P        FR1        3             0        0
# 18  R1092J        FR1        0             0        2
# 19  R1092J        FR1        1             0        2

# %% [markdown]
# ### 3b. Run Raw + Epoched EEG comparisons (iEEG)

# %%
reader = BIDSReader(root="/data/LTP_BIDS/FR1/", subject="R1060M", task="FR1", session=0)
events = reader.load_events().query("trial_type == 'WORD'")
eeg = reader.load_epochs(events=events, acquisition="monopolar", tmin=0, tmax=0.2, preload=True)

conv_eeg = BIDSReader.convert_unit(eeg, "uV", copy=True)
# Out:
# Extracting EDF parameters from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_acq-monopolar_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_events.tsv.
# Reading channel info from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_acq-monopolar_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_space-MNI152NLin6ASym_electrodes.tsv.
# Used Annotations descriptions: ['COUNTDOWN_END', 'COUNTDOWN_START', 'DISTRACT_END', 'DISTRACT_START', 'ORIENT', 'PRACTICE_DISTRACT_END', 'PRACTICE_DISTRACT_START', 'PRACTICE_REC_END', 'PRACTICE_REC_START', 'PRACTICE_WORD', 'PROB', 'REC_END', 'REC_START', 'REC_WORD', 'REC_WORD_VV', 'SESS_END', 'SESS_START', 'START', 'STOP', 'TRIAL', 'WORD']
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 300 events and 101 original time points ...
# 0 bad epochs dropped

# %%
conv_eeg.load_data()
conv_eeg._data = np.round(conv_eeg._data)

# %%
cmlreader = cml.CMLReader(subject="R1060M", experiment="FR1", session=0, montage=0, localization=0)
contacts = cmlreader.load("contacts")
events = cmlreader.load("events").query("type == 'WORD'")
cml_eeg = cmlreader.load_eeg(scheme=contacts, events=events, rel_start=0, rel_stop=200)

# %%
for _, row in df_ram.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])
    loc = int(row["localization"])
    mon = int(row["montage"])

    for acq in ["contacts", "pairs"]:
        # --- Raw ---
        try:
            result = RawSignalPipeline(
                sub, exp, sess, ram_bids_root, ram_out_path,
                skip_if_exists=SKIP_IF_EXISTS,
                localization=loc, montage=mon,
                acquisition=acq,verbose=True
            ).run()
            tag = "SKIP" if isinstance(result, dict) and result.get("skipped") else "DONE"
            print(f"[{tag}] Raw/{acq}  | {sub} | {exp} | {sess}")
        except Exception as e:
            print(f"[FAIL] Raw/{acq}  | {sub} | {exp} | {sess}: {e}")

        # --- Epoched ---
        try:
            result = EpochedPipeline(
                sub, exp, sess, ram_bids_root, ram_out_path,
                skip_if_exists=SKIP_IF_EXISTS,
                localization=loc, montage=mon,
                acquisition=acq,
                tmin=tmin, tmax=tmax,
            ).run()
            tag = "SKIP" if isinstance(result, dict) and result.get("skipped") else "DONE"
            print(f"[{tag}] Epoch/{acq} | {sub} | {exp} | {sess}")
        except Exception as e:
            print(f"[FAIL] Epoch/{acq} | {sub} | {exp} | {sess}: {e}")
# Out:
# Extracting EDF parameters from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_acq-monopolar_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_events.tsv.
# Reading channel info from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_acq-monopolar_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_space-MNI152NLin6ASym_electrodes.tsv.
# Reading 0 ... 1668499  =      0.000 ...  3336.998 secs...
# [FAIL] Raw/contacts  | R1060M | FR1 | 0: name 'np' is not defined
# Extracting EDF parameters from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_acq-monopolar_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_events.tsv.
# Reading channel info from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_acq-monopolar_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/FR1/sub-R1060M/ses-0/ieeg/sub-R1060M_ses-0_task-FR1_space-MNI152NLin6ASym_electrodes.tsv.
# Used Annotations descriptions: ['COUNTDOWN_END', 'COUNTDOWN_START', 'DISTRACT_END', 'DISTRACT_START', 'ORIENT', 'PRACTICE_DISTRACT_END', 'PRACTICE_DISTRACT_START', 'PRACTICE_REC_END', 'PRACTICE_REC_START', 'PRACTICE_WORD', 'PROB', 'REC_END', 'REC_START', 'REC_WORD', 'REC_WORD_VV', 'SESS_END', 'SESS_START', 'START', 'STOP', 'TRIAL', 'WORD']
# Not setting metadata
# 737 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 737 events and 751 original time points ...
# KeyboardInterrupt

# %% [markdown]
# ### 3c. Run Behavioral Events comparison (iEEG)

# %%
for _, row in df_ram.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])
    loc = int(row["localization"])
    mon = int(row["montage"])

    try:
        result = EventsPipeline(
            sub, exp, sess, ram_bids_root, ram_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
            localization=loc, montage=mon,
        ).run()
        tag = "SKIP" if isinstance(result, dict) and result.get("skipped") else "DONE"
        print(f"[{tag}] Events | {sub} | {exp} | {sess}")
    except Exception as e:
        print(f"[FAIL] Events | {sub} | {exp} | {sess}: {e}")

# %% [markdown]
# ### 3d. Run Montage comparison (iEEG only)

# %%
for _, row in df_ram.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])
    loc = int(row["localization"])
    mon = int(row["montage"])

    for acq in ["contacts", "pairs"]:
        try:
            result = MontagePipeline(
                sub, exp, sess, ram_bids_root, ram_out_path,
                skip_if_exists=SKIP_IF_EXISTS,
                localization=loc, montage=mon,
                acquisition=acq,
            ).run()
            tag = "SKIP" if isinstance(result, dict) and result.get("skipped") else "DONE"
            print(f"[{tag}] Montage/{acq} | {sub} | {exp} | {sess}")
        except Exception as e:
            print(f"[FAIL] Montage/{acq} | {sub} | {exp} | {sess}: {e}")

# %% [markdown]
# ### 3e. Aggregate RAM results & plot

# %%
ram_final = "ram_final_unit_convert_round/"
os.makedirs(ram_final, exist_ok=True)

FILE_CATEGORIES_RAM = [
    "df_raw", "df_raw_summary", "df_time",
    "df_behavior_summary",
    "df_epoch", "df_epoch_summary", "df_epoch_time",
    "df_contacts_summary", "df_contacts_column_summary", "df_contacts_mismatches",
    "df_pairs_summary", "df_pairs_column_summary", "df_pairs_mismatches",
    "df_montage_summary",
]

ram_dfs = {}
for cat in FILE_CATEGORIES_RAM:
    files = [
        os.path.join(dp, f)
        for dp, _, fns in os.walk(ram_out_path)
        for f in fns
        if f.endswith(".csv") and f.startswith(cat + "_")
    ]
    if not files:
        print(f"Skipping {cat} (no files)")
        continue
    df_all = load_and_concat(files)
    ram_dfs[cat] = df_all
    outfile = os.path.join(ram_final, f"{cat}_all.csv")
    df_all.to_csv(outfile, index=False)
    print(f"{cat}: {len(files)} files -> {outfile}")
# Out:
# Removed 70 duplicate rows
# df_raw: 127 files -> ram_final_unit_convert/df_raw_all.csv
# Removed 2 duplicate rows
# df_raw_summary: 64 files -> ram_final_unit_convert/df_raw_summary_all.csv
# Removed 34 duplicate rows
# df_time: 65 files -> ram_final_unit_convert/df_time_all.csv
# Skipping df_behavior_summary (no files)
# Removed 1307 duplicate rows
# df_epoch: 258 files -> ram_final_unit_convert/df_epoch_all.csv
# Removed 21 duplicate rows
# df_epoch_summary: 65 files -> ram_final_unit_convert/df_epoch_summary_all.csv
# df_epoch_time: 64 files -> ram_final_unit_convert/df_epoch_time_all.csv
# Skipping df_contacts_summary (no files)
# Skipping df_contacts_column_summary (no files)
# Skipping df_contacts_mismatches (no files)
# Skipping df_pairs_summary (no files)
# Skipping df_pairs_column_summary (no files)
# Skipping df_pairs_mismatches (no files)
# Skipping df_montage_summary (no files)

# %%
# --- Raw signal plots ---
if "df_raw_summary" in ram_dfs:
    plot_comparison_results(ram_dfs["df_raw_summary"], "mean_abs_diff", "std_diff", col_label="Mean Abs Signal Diff", title="Raw Signal Mean Difference")
    plot_comparison_results(ram_dfs["df_raw_summary"], "mse", col_label="MSE Raw Signal", title="Raw Signal MSE")
    plot_comparison_results(ram_dfs["df_raw_summary"], "n_exact_diff_channels", title="Raw Signal Number of Differing EEG Channels (No Tolerance)")
    plot_comparison_results(ram_dfs["df_raw_summary"], "n_close_diff_channels", title="Raw Signal Number of Differing EEG Channels (Tolerance)")
    
if "df_epoch" in ram_dfs:
    plot_comparison_results(ram_dfs["df_epoch_summary"], "mean_abs_diff", "std_diff", col_label="Mean Abs Signal Diff", title="Epochs Mean Difference")
    plot_comparison_results(ram_dfs["df_epoch_summary"], "mse", col_label="MSE Epochs", title="Raw Signal MSE")
    plot_comparison_results(ram_dfs["df_epoch_summary"], "n_exact_diff_channels", title="Epochs Number of Differing EEG Channels (No Tolerance)")
    plot_comparison_results(ram_dfs["df_epoch_summary"], "n_close_diff_channels", title="Epochs Number of Differing EEG Channels (Tolerance)")

# --- Time coord plots ---
if "df_time" in ram_dfs:
    plot_comparison_results(ram_dfs["df_time"], "mean_abs_time_diff", "std_time_diff", col_label="Mean Abs Time Diff", title="Raw Signal Time Indices Mean Difference")
    plot_comparison_results(ram_dfs["df_time"], "mse_time", col_label="MSE Time", title="Raw Signal Time Indices MSE")
    plot_comparison_results(ram_dfs["df_epoch_time"], "mean_abs_time_diff", "std_time_diff", col_label="Mean Abs Time Diff", title="Epochs Time Indices Mean Difference")
    plot_comparison_results(ram_dfs["df_epoch_time"], "mse_time", col_label="MSE Time", title="Epochs Time Indices MSE")

# --- Behavioral plots ---
if "df_behavior_summary" in ram_dfs:
    plot_comparison_results(ram_dfs["df_behavior_summary"], "n_differing_columns", title="Events Number of Differing Columns")

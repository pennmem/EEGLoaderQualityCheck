# %% [markdown]
# # CML vs BIDS Comparison
#
# Using `bids_validation` package with `BIDSReader`.

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

import os
import numpy as np
import pandas as pd
import cmlreaders as cml
import matplotlib.pyplot as plt
# %matplotlib inline

from eeg_validation import (
    EventsPipeline,
    RawSignalPipeline,
    EpochedPipeline,
    MontagePipeline,
)
from eeg_validation.io import load_and_concat
from eeg_validation.plotting import plot_comparison_results

pd.options.display.max_rows = 100
pd.options.display.max_columns = 50

# %% [markdown]
# ## 1. Configuration

# %%
# ---- Shared settings ----
REL_START = 200      # ms
REL_STOP  = 1000     # ms
BUFFER_MS = 1000     # ms
tmin = -BUFFER_MS
tmax = REL_STOP + BUFFER_MS

MAX_SUBJECTS = 10
SUBJECTS_TO_EXCLUDE = {"LTP001", "LTP9992", "LTP9993"}

# Set to True to skip sessions whose output CSVs already exist
SKIP_IF_EXISTS = False

# %% [markdown]
# ---
# ## 2. Scalp / LTP Comparisons

# %% [markdown]
# ### 2a. Select subjects & sessions

# %%
ltp_experiments = ["ValueCourier"]
ltp_bids_root   = "/data/LTP_BIDS/"
ltp_out_path    = "ltp_results/"

df = cml.get_data_index()
df_exp = df[df["experiment"].isin(ltp_experiments)].copy()
df_exp = df_exp[~df_exp["subject"].isin(SUBJECTS_TO_EXCLUDE)]

dfs = []
for exp in ltp_experiments:
    df_this = df_exp[df_exp["experiment"] == exp]
    subjects = df_this["subject"].drop_duplicates().sort_values().head(MAX_SUBJECTS)
    dfs.append(df_this[df_this["subject"].isin(subjects)])

df_ltp = pd.concat(dfs, ignore_index=True)
print(f"LTP jobs: {len(df_ltp)} sessions across {df_ltp['subject'].nunique()} subjects")
df_ltp[["subject", "experiment", "session"]].head(20)
# Out:
# LTP jobs: 28 sessions across 8 subjects
#    subject    experiment  session
# 0   LTP606  ValueCourier        0
# 1   LTP606  ValueCourier        1
# 2   LTP606  ValueCourier        2
# 3   LTP606  ValueCourier        3
# 4   LTP606  ValueCourier        4
# 5   LTP606  ValueCourier        5
# 6   LTP607  ValueCourier        0
# 7   LTP607  ValueCourier        1
# 8   LTP607  ValueCourier        2
# 9   LTP607  ValueCourier        3
# 10  LTP607  ValueCourier        4
# 11  LTP607  ValueCourier        5
# 12  LTP609  ValueCourier        0
# 13  LTP609  ValueCourier        1
# 14  LTP609  ValueCourier        2
# 15  LTP609  ValueCourier        3
# 16  LTP609  ValueCourier        4
# 17  LTP609  ValueCourier        5
# 18  LTP610  ValueCourier        0
# 19  LTP610  ValueCourier        1

# %% [markdown]
# ### 2b. Run Raw + Epoched EEG comparisons

# %%
for _, row in df_ltp.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])
    bids_root = ltp_bids_root

    # --- Raw ---
    # try:
    #     result = RawSignalPipeline(
    #         sub, exp, sess, bids_root, ltp_out_path,
    #         skip_if_exists=SKIP_IF_EXISTS,
    #     ).run()
    #     tag = "SKIP" if result.get("skipped") else "DONE"
    #     print(f"[{tag}] Raw  | {sub} | {exp} | {sess}")
    # except Exception as e:
    #     print(f"[FAIL] Raw  | {sub} | {exp} | {sess}: {e}")

    # --- Epoched ---
    try:
        result = EpochedPipeline(
            sub, exp, sess, bids_root, ltp_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
            tmin=tmin, tmax=tmax,
        ).run()
        tag = "SKIP" if result.get("skipped") else "DONE"
        print(f"[{tag}] Epoch | {sub} | {exp} | {sess}")
    except Exception as e:
        print(f"[FAIL] Epoch | {sub} | {exp} | {sess}: {e}")
# Out:
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Extracting EDF parameters from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_eeg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_events.tsv.
# Reading channel info from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_space-CapTrak_electrodes.tsv.
# [DONE] Raw  | LTP606 | ValueCourier | 0
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 13 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 2 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 2 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 2 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 7 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 7 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 7 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 7 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 29 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 29 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 3 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 3 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 50 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 50 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 5 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 5 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 5 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# [DONE] Epoch | LTP606 | ValueCourier | 0
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Extracting EDF parameters from /data/LTP_BIDS/sub-LTP606/ses-1/eeg/sub-LTP606_ses-1_task-valuecourier_eeg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/sub-LTP606/ses-1/eeg/sub-LTP606_ses-1_task-valuecourier_events.tsv.
# Reading channel info from /data/LTP_BIDS/sub-LTP606/ses-1/eeg/sub-LTP606_ses-1_task-valuecourier_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/sub-LTP606/ses-1/eeg/sub-LTP606_ses-1_space-CapTrak_electrodes.tsv.
# [DONE] Raw  | LTP606 | ValueCourier | 1
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 11 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 10 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 10 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 39 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 39 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 3 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 3 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 69 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 69 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 10 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 10 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 10 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 150 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 150 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/1/ephys/current_processed/LTP606_session_1.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11229183  =      0.000 ...  5483.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# [DONE] Epoch | LTP606 | ValueCourier | 1
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# Extracting EDF parameters from /data/LTP_BIDS/sub-LTP606/ses-2/eeg/sub-LTP606_ses-2_task-valuecourier_eeg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/sub-LTP606/ses-2/eeg/sub-LTP606_ses-2_task-valuecourier_events.tsv.
# Reading channel info from /data/LTP_BIDS/sub-LTP606/ses-2/eeg/sub-LTP606_ses-2_task-valuecourier_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/sub-LTP606/ses-2/eeg/sub-LTP606_ses-2_space-CapTrak_electrodes.tsv.
# [DONE] Raw  | LTP606 | ValueCourier | 2
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 10 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 10 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# Not setting metadata
# 26 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 26 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# Not setting metadata
# 8 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 8 events and 6145 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/2/ephys/current_processed/LTP606_session_2.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10551295  =      0.000 ...  5152.000 secs...
# KeyboardInterrupt

# %% [markdown]
# ### 2c. Run Behavioral Events comparison

# %%
for _, row in df_ltp.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])

    try:
        result = EventsPipeline(
            sub, exp, sess, ltp_bids_root, ltp_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
        ).run()
        tag = "SKIP" if result.get("skipped") else "DONE"
        print(f"[{tag}] Events | {sub} | {exp} | {sess}: {result.get('reason')}")
    except Exception as e:
        print(f"[FAIL] Events | {sub} | {exp} | {sess}: {e}")
# Out:
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0         23440
# 1         31922
# 2        468068
# 3        646089
# 4        646183
#          ...
# 237    10769845
# 238    10769847
# 239    10774076
# 240    10774082
# 241    10774084
# Name: sample, Length: 242, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 0: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0         26913
# 1         35692
# 2         40775
# 3         44050
# 4         46917
#          ...
# 322    11185152
# 323    11185154
# 324    11188636
# 325    11188640
# 326    11188642
# Name: sample, Length: 327, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 1: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0          1870
# 1          4027
# 2          5323
# 3          5831
# 4          6755
#          ...
# 304    10513236
# 305    10513236
# 306    10518356
# 307    10518362
# 308    10518364
# Name: sample, Length: 309, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 2: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0        17126
# 1        19110
# 2        20114
# 3        20931
# 4        21477
#         ...
# 316    9440931
# 317    9440931
# 318    9444682
# 319    9444687
# 320    9444687
# Name: sample, Length: 321, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 3: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0         8640
# 1         9910
# 2        10283
# 3        10658
# 4        10961
#         ...
# 327    9685087
# 328    9685087
# 329    9688432
# 330    9688438
# 331    9688438
# Name: sample, Length: 332, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 4: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0        54228
# 1        56177
# 2        56654
# 3        57166
# 4        57574
#         ...
# 180    5428009
# 181    5460438
# 182    5575424
# 183    5575426
# 184    5578938
# Name: sample, Length: 185, dtype: int64
# [DONE] Events | LTP606 | ValueCourier | 5: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0         31959
# 1         38287
# 2        474408
# 3        695343
# 4        695433
#          ...
# 255    11094864
# 256    11094866
# 257    11101112
# 258    11101118
# 259    11101120
# Name: sample, Length: 260, dtype: int64
# [DONE] Events | LTP607 | ValueCourier | 0: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0         20907
# 1         33130
# 2         34939
# 3         36606
# 4         37359
#          ...
# 356    10828051
# 357    10828051
# 358    10832524
# 359    10832530
# 360    10832530
# Name: sample, Length: 361, dtype: int64
# [DONE] Events | LTP607 | ValueCourier | 1: None
# HERE
# eeg
# load_bids_events
# [SKIP] Events | LTP607 | ValueCourier | 2: bids_events_not_found
# HERE
# eeg
# load_bids_events
# [SKIP] Events | LTP607 | ValueCourier | 3: bids_events_not_found
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0        13115
# 1        17248
# 2        18032
# 3        18409
# 4        18714
#         ...
# 356    9922591
# 357    9922591
# 358    9926179
# 359    9926183
# 360    9926185
# Name: sample, Length: 361, dtype: int64
# [DONE] Events | LTP607 | ValueCourier | 4: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0        16455
# 1        22639
# 2        23047
# 3        23387
# 4        23966
#         ...
# 366    9505791
# 367    9505791
# 368    9509135
# 369    9509141
# 370    9509143
# Name: sample, Length: 371, dtype: int64
# [DONE] Events | LTP607 | ValueCourier | 5: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0          6636
# 1         18768
# 2        454867
# 3        674643
# 4        674737
#          ...
# 233    11269067
# 234    11269067
# 235    11274901
# 236    11274905
# 237    11274908
# Name: sample, Length: 238, dtype: int64
# [DONE] Events | LTP609 | ValueCourier | 0: None
# HERE
# eeg
# load_bids_events
# [SKIP] Events | LTP609 | ValueCourier | 1: bids_events_not_found
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 329   -1
# 330   -1
# 331   -1
# 332   -1
# 333   -1
# Name: sample, Length: 334, dtype: int64
# [DONE] Events | LTP609 | ValueCourier | 2: None
# HERE
# eeg
# load_bids_events
# load evs
# HERE3
# 0        14704
# 1        31300
# 2        33856
# 3        35222
# 4        35732
#         ...
# 335    9968318
# 336    9968318
# 337    9973440
# 338    9973448
# 339    9973448
# Name: sample, Length: 340, dtype: int64
# [DONE] Events | LTP609 | ValueCourier | 3: None
# HERE
# eeg
# load_bids_events
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       2 sub, exp, sess = row["subject"], row["experiment"], int(row["session"])
#       4 try:
#       5     result = EventsPipeline(
#       6         sub, exp, sess, ltp_bids_root, ltp_out_path,
#       7         skip_if_exists=SKIP_IF_EXISTS,
# ----> 8     ).run()
#       9     tag = "SKIP" if result.get("skipped") else "DONE"
#      10     print(f"[{tag}] Events | {sub} | {exp} | {sess}: {result.get('reason')}")
#
# File ~/eeg-validation/eeg_validation/pipelines/base.py:65, in BasePipeline.run(self)
#      62 if self.skip_if_exists and all(os.path.exists(p) for p in paths):
#      63     return {"skipped": True, "reason": "outputs_exist", "paths": paths}
# ---> 65 return self._run()
#
# File ~/eeg-validation/eeg_validation/pipelines/events.py:41, in EventsPipeline._run(self)
#      39 print(self.reader.eeg_type)
#      40 try:
# ---> 41     evs_bids = load_bids_events(reader=self.reader, event_type=self.reader.eeg_type)
#      42 except Exception as e:
#      43     return {"skipped": True, "reason": "bids_events_not_found", "error": str(e)}
#
# File ~/eeg-validation/eeg_validation/loaders/bids.py:74, in load_bids_events(reader, event_type)
#      63 """Load BIDS events via BIDSReader.
#      64
#      65 Parameters
#    (...)
#      71     EEG-aligned events.
#      72 """
#      73 print("load_bids_events")
# ---> 74 evs = reader.load_events(event_type=event_type)
#      75 print("load evs")
#      76 return evs
#
# File ~/bidsreader/bidsreader/_errorwrap.py:21, in public_api.<locals>.wrapper(*args, **kwargs)
#      18 @wraps(func)
#      19 def wrapper(*args, **kwargs):
#      20     try:
# ---> 21         return func(*args, **kwargs)
#      23     # If it's already one of yours, don't touch it.
#      24     except BIDSReaderError:
#
# File ~/bidsreader/bidsreader/bidsreader.py:253, in BIDSReader.load_events(self, event_type)
#     245 suffix = "beh" if event_type == "beh" else "events"
#     247 bp = self._bp(
#     248     datatype=event_type,
#     249     suffix=suffix,
#     250     extension=".tsv",
#     251 )
# --> 253 matches = bp.match()
#     254 if not matches:
#     255     raise FileNotFoundBIDSError(f"load_events: no file matched for {bp}")
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne_bids/path.py:1049, in BIDSPath.match(self, ignore_json, check)
#    1041 if self.root is None:
#    1042     raise RuntimeError(
#    1043         "Cannot match basenames if `root` "
#    1044         "attribute is not set. Please set the"
#    1045         "BIDS root directory path to `root` via "
#    1046         "BIDSPath.update()."
#    1047     )
# -> 1049 paths = _return_root_paths(
#    1050     self.root, datatype=self.datatype, ignore_json=ignore_json
#    1051 )
#    1053 fnames = _filter_fnames(
#    1054     paths, suffix=self.suffix, extension=self.extension, **self.entities
#    1055 )
#    1057 bids_paths = _fnames_to_bidspaths(fnames, self.root, check=check)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne_bids/path.py:2433, in _return_root_paths(root, datatype, ignore_json)
#    2430 # Only keep files (not directories), and omit the JSON sidecars
#    2431 # if ignore_json is True.
#    2432 if ignore_json:
# -> 2433     paths = [p for p in paths if p.is_file() and p.suffix != ".json"]
#    2434 else:
#    2435     paths = [p for p in paths if p.is_file()]
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/mne_bids/path.py:2433, in <listcomp>(.0)
#    2430 # Only keep files (not directories), and omit the JSON sidecars
#    2431 # if ignore_json is True.
#    2432 if ignore_json:
# -> 2433     paths = [p for p in paths if p.is_file() and p.suffix != ".json"]
#    2434 else:
#    2435     paths = [p for p in paths if p.is_file()]
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/pathlib.py:968, in Path.rglob(self, pattern)
#     966     pattern_parts.append('')
#     967 selector = _make_selector(("**",) + tuple(pattern_parts), self._flavour)
# --> 968 for p in selector.select_from(self):
#     969     yield p
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/pathlib.py:407, in _RecursiveWildcardSelector._select_from(self, parent_path, is_dir, exists, scandir)
#     405 try:
#     406     successor_select = self.successor._select_from
# --> 407     for starting_point in self._iterate_directories(parent_path, is_dir, scandir):
#     408         for p in successor_select(starting_point, is_dir, exists, scandir):
#     409             if p not in yielded:
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/pathlib.py:397, in _RecursiveWildcardSelector._iterate_directories(self, parent_path, is_dir, scandir)
#     395         if entry_is_dir:
#     396             path = parent_path._make_child_relpath(entry.name)
# --> 397             for p in self._iterate_directories(path, is_dir, scandir):
#     398                 yield p
#     399 except PermissionError:
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/pathlib.py:397, in _RecursiveWildcardSelector._iterate_directories(self, parent_path, is_dir, scandir)
#     395         if entry_is_dir:
#     396             path = parent_path._make_child_relpath(entry.name)
# --> 397             for p in self._iterate_directories(path, is_dir, scandir):
#     398                 yield p
#     399 except PermissionError:
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/pathlib.py:397, in _RecursiveWildcardSelector._iterate_directories(self, parent_path, is_dir, scandir)
#     395         if entry_is_dir:
#     396             path = parent_path._make_child_relpath(entry.name)
# --> 397             for p in self._iterate_directories(path, is_dir, scandir):
#     398                 yield p
#     399 except PermissionError:
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/pathlib.py:386, in _RecursiveWildcardSelector._iterate_directories(self, parent_path, is_dir, scandir)
#     384 yield parent_path
#     385 try:
# --> 386     with scandir(parent_path) as scandir_it:
#     387         entries = list(scandir_it)
#     388     for entry in entries:
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/pathlib.py:938, in Path._scandir(self)
#     934 def _scandir(self):
#     935     # bpo-24132: a future version of pathlib will support subclassing of
#     936     # pathlib.Path to customize how the filesystem is accessed. This
#     937     # includes scandir(), which is used to implement glob().
# --> 938     return os.scandir(self)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2d. Aggregate LTP results & plot

# %%
ltp_final = "ltp_final/"
os.makedirs(ltp_final, exist_ok=True)

FILE_CATEGORIES = [
    "df_raw", "df_raw_summary", "df_raw_time",
    "df_behavior_summary",
    "df_epoch", "df_epoch_summary", "df_epoch_time",
]

ltp_dfs = {}
for cat in FILE_CATEGORIES:
    files = [
        os.path.join(dp, f)
        for dp, _, fns in os.walk(ltp_out_path)
        for f in fns
        if f.endswith(".csv") and f.startswith(cat + "_")
    ]
    if not files:
        print(f"Skipping {cat} (no files)")
        continue
    df_all = load_and_concat(files)
    ltp_dfs[cat] = df_all
    outfile = os.path.join(ltp_final, f"{cat}_all.csv")
    df_all.to_csv(outfile, index=False)
    print(f"{cat}: {len(files)} files -> {outfile}")

# %%
# --- Raw signal plots ---
if "df_raw_summary" in ltp_dfs:
    plot_comparison_results(ltp_dfs["df_raw_summary"], "mean_abs_diff", "std_diff", col_label="Mean Abs Signal Diff")
    plot_comparison_results(ltp_dfs["df_raw_summary"], "mse", col_label="MSE Raw Signal")
    plot_comparison_results(ltp_dfs["df_raw_summary"], "n_exact_diff_channels")
    plot_comparison_results(ltp_dfs["df_raw_summary"], "n_close_diff_channels")

# --- Time coord plots ---
if "df_raw_time" in ltp_dfs:
    plot_comparison_results(ltp_dfs["df_raw_time"], "mean_abs_time_diff", "std_time_diff", col_label="Mean Abs Time Diff")
    plot_comparison_results(ltp_dfs["df_raw_time"], "mse_time", col_label="MSE Time")

# --- Behavioral plots ---
if "df_behavior_summary" in ltp_dfs:
    plot_comparison_results(ltp_dfs["df_behavior_summary"], "n_differing_columns")

# %% [markdown]
# ---
# ## 3. iEEG / RAM Comparisons

# %% [markdown]
# ### 3a. Select subjects & sessions

# %%
ram_experiments = ["FR1"]
ram_bids_root   = "/data/LTP_BIDS/FR1"
ram_out_path    = "ram_results/"

ram_subjects_to_include = [
    'R1060M', 'R1061T', 'R1065J', 'R1066P', 'R1092J',
    'R1108J', 'R1111M', 'R1207J', 'R1226D', 'R1230J',
    'R1236J', 'R1243T', 'R1247P', 'R1292E', 'R1308T',
    'R1310J', 'R1328E', 'R1332M', 'R1334T', 'R1337E',
    'R1341T', 'R1354E', 'R1395M', 'R1542J',
]

df = cml.get_data_index()
df_exp = df[df["experiment"].isin(ram_experiments)].copy()
df_exp = df_exp[~df_exp["subject"].isin(SUBJECTS_TO_EXCLUDE)]
df_exp = df_exp[df_exp["subject"].isin(ram_subjects_to_include)]

dfs = []
for exp in ram_experiments:
    df_this = df_exp[df_exp["experiment"] == exp]
    subjects = df_this["subject"].drop_duplicates().sort_values().head(MAX_SUBJECTS)
    dfs.append(df_this[df_this["subject"].isin(subjects)])

df_ram = pd.concat(dfs, ignore_index=True)
print(f"RAM jobs: {len(df_ram)} sessions across {df_ram['subject'].nunique()} subjects")
df_ram[["subject", "experiment", "session", "localization", "montage"]].head(20)
# Out:
# RAM jobs: 39 sessions across 10 subjects
#    subject experiment  session  localization  montage
# 0   R1060M        FR1        0             0        0
# 1   R1060M        FR1        1             0        0
# 2   R1060M        FR1        2             0        0
# 3   R1060M        FR1        3             0        0
# 4   R1061T        FR1        0             0        0
# 5   R1061T        FR1        1             0        0
# 6   R1061T        FR1        2             0        0
# 7   R1061T        FR1        3             0        0
# 8   R1065J        FR1        0             0        0
# 9   R1065J        FR1        1             0        0
# 10  R1065J        FR1        2             0        0
# 11  R1065J        FR1        3             0        0
# 12  R1065J        FR1        4             0        0
# 13  R1065J        FR1        5             0        0
# 14  R1066P        FR1        0             0        0
# 15  R1066P        FR1        1             0        0
# 16  R1066P        FR1        2             0        0
# 17  R1066P        FR1        3             0        0
# 18  R1092J        FR1        0             0        2
# 19  R1092J        FR1        1             0        2

# %% [markdown]
# ### 3b. Run Raw + Epoched EEG comparisons (iEEG)

# %%
for _, row in df_ram.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])
    loc = int(row["localization"])
    mon = int(row["montage"])

    # --- Raw ---
    try:
        result = RawSignalPipeline(
            sub, exp, sess, ram_bids_root, ram_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
            localization=loc, montage=mon,
        ).run()
        tag = "SKIP" if result.get("skipped") else "DONE"
        print(f"[{tag}] Raw  | {sub} | {exp} | {sess}")
    except Exception as e:
        print(f"[FAIL] Raw  | {sub} | {exp} | {sess}: {e}")

    # --- Epoched ---
    try:
        result = EpochedPipeline(
            sub, exp, sess, ram_bids_root, ram_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
            localization=loc, montage=mon,
            tmin=tmin, tmax=tmax,
        ).run()
        tag = "SKIP" if result.get("skipped") else "DONE"
        print(f"[{tag}] Epoch | {sub} | {exp} | {sess}")
    except Exception as e:
        print(f"[FAIL] Epoch | {sub} | {exp} | {sess}: {e}")

# %% [markdown]
# ### 3c. Run Behavioral Events comparison (iEEG)

# %%
for _, row in df_ram.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])
    loc = int(row["localization"])
    mon = int(row["montage"])

    try:
        result = EventsPipeline(
            sub, exp, sess, ram_bids_root, ram_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
            localization=loc, montage=mon,
        ).run()
        tag = "SKIP" if result.get("skipped") else "DONE"
        print(f"[{tag}] Events | {sub} | {exp} | {sess}")
    except Exception as e:
        print(f"[FAIL] Events | {sub} | {exp} | {sess}: {e}")
# Out:
# 0         7991
# 1        81260
# 2        86473
# 3        88269
# 4        89586
#         ...
# 771    1641135
# 772    1641901
# 773    1647686
# 774    1652511
# 775    1664067
# Name: sample, Length: 776, dtype: int64
# [DONE] Events | R1060M | FR1 | 0
# 0        15858
# 1        29421
# 2        34635
# 3        36613
# 4        37830
#         ...
# 868    1375019
# 869    1376309
# 870    1377615
# 871    1379657
# 872    1387346
# Name: sample, Length: 873, dtype: int64
# [DONE] Events | R1060M | FR1 | 1
# 0        19451
# 1       151925
# 2       157139
# 3       159025
# 4       160242
#         ...
# 880    1444420
# 881    1445742
# 882    1452992
# 883    1457308
# 884    1461032
# Name: sample, Length: 885, dtype: int64
# [DONE] Events | R1060M | FR1 | 2
# 0        9300
# 1       39125
# 2       44338
# 3       46159
# 4       47426
#         ...
# 548    806955
# 549    810054
# 550    819708
# 551    825815
# 552    825815
# Name: sample, Length: 553, dtype: int64
# [DONE] Events | R1060M | FR1 | 3
# 0       251997
# 1       270328
# 2       280756
# 3       284548
# 4       287097
#         ...
# 843    3031550
# 844    3034839
# 845    3043613
# 846    3053341
# 847    3067052
# Name: sample, Length: 848, dtype: int64
# [DONE] Events | R1061T | FR1 | 0
# 0        20174
# 1        51419
# 2        61847
# 3        65821
# 4        68321
#         ...
# 666    2325735
# 667    2327743
# 668    2343429
# 669    2362393
# 670    2362393
# Name: sample, Length: 671, dtype: int64
# [DONE] Events | R1061T | FR1 | 1
# 0       346039
# 1       359179
# 2       369607
# 3       373415
# 4       375798
#         ...
# 807    2878716
# 808    2887608
# 809    2889421
# 810    2908726
# 811    2919455
# Name: sample, Length: 812, dtype: int64
# [DONE] Events | R1061T | FR1 | 2
# 0       172825
# 1       183575
# 2       194003
# 3       197877
# 4       200395
#         ...
# 858    2718560
# 859    2722980
# 860    2725648
# 861    2726360
# 862    2731448
# Name: sample, Length: 863, dtype: int64
# [DONE] Events | R1061T | FR1 | 3
# 0       318812
# 1       336441
# 2       346869
# 3       350709
# 4       353194
#         ...
# 872    2963890
# 873    2964055
# 874    2965062
# 875    2976412
# 876    2984823
# Name: sample, Length: 877, dtype: int64
# [DONE] Events | R1065J | FR1 | 0
# 0       270988
# 1       289401
# 2       299829
# 3       303503
# 4       306103
#         ...
# 902    2884815
# 903    2887435
# 904    2891271
# 905    2910642
# 906    2913467
# Name: sample, Length: 907, dtype: int64
# [DONE] Events | R1065J | FR1 | 1
# 0        56622
# 1        70931
# 2        81357
# 3        84980
# 4        87480
#         ...
# 906    2626653
# 907    2627740
# 908    2637774
# 909    2647542
# 910    2653117
# Name: sample, Length: 911, dtype: int64
# [DONE] Events | R1065J | FR1 | 2
# 0        48653
# 1        60528
# 2        70956
# 3        74481
# 4        76865
#         ...
# 908    2590653
# 909    2592534
# 910    2595771
# 911    2618654
# 912    2625250
# Name: sample, Length: 913, dtype: int64
# [DONE] Events | R1065J | FR1 | 3
# 0        82493
# 1        93784
# 2       104213
# 3       107971
# 4       110505
#         ...
# 889    2601047
# 890    2602098
# 891    2621028
# 892    2632112
# 893    2634887
# Name: sample, Length: 894, dtype: int64
# [DONE] Events | R1065J | FR1 | 4
# 0       164757
# 1       178170
# 2       188598
# 3       192289
# 4       194706
#         ...
# 935    2656477
# 936    2657991
# 937    2659970
# 938    2680185
# 939    2688927
# Name: sample, Length: 940, dtype: int64
# [DONE] Events | R1065J | FR1 | 5
# 0       314016
# 1       324060
# 2       329274
# 3       331220
# 4       332486
#         ...
# 845    1879990
# 846    1880589
# 847    1892844
# 848    1899997
# 849    1899997
# Name: sample, Length: 850, dtype: int64
# [DONE] Events | R1066P | FR1 | 0
# 0       305490
# 1       325404
# 2       330618
# 3       332447
# 4       333748
#         ...
# 411    1070677
# 412    1071120
# 413    1084787
# 414    1102542
# 415    1102542
# Name: sample, Length: 416, dtype: int64
# [DONE] Events | R1066P | FR1 | 1
# 0       113226
# 1       159538
# 2       164752
# 3       166580
# 4       167830
#         ...
# 929    1788798
# 930    1789260
# 931    1789814
# 932    1802603
# 933    1807377
# Name: sample, Length: 934, dtype: int64
# [DONE] Events | R1066P | FR1 | 2
# 0       161935
# 1       170028
# 2       175241
# 3       177179
# 4       178420
#         ...
# 933    1784771
# 934    1785559
# 935    1787555
# 936    1791693
# 937    1797280
# Name: sample, Length: 938, dtype: int64
# [DONE] Events | R1066P | FR1 | 3
# 0        32444
# 1        45950
# 2        56378
# 3        59968
# 4        62419
#         ...
# 893    2589454
# 894    2591705
# 895    2608826
# 896    2613051
# 897    2626911
# Name: sample, Length: 898, dtype: int64
# [DONE] Events | R1092J | FR1 | 0
# 0        27769
# 1        45485
# 2        55913
# 3        59702
# 4        62236
#         ...
# 939    2600356
# 940    2604270
# 941    2613718
# 942    2619234
# 943    2634311
# Name: sample, Length: 944, dtype: int64
# [DONE] Events | R1092J | FR1 | 1
# 0         5568
# 1        30203
# 2        40631
# 3        40640
# 4        44173
#         ...
# 906    2621091
# 907    2625443
# 908    2627407
# 909    2635630
# 910    2645271
# Name: sample, Length: 911, dtype: int64
# [DONE] Events | R1092J | FR1 | 2
# 0        41575
# 1        97264
# 2       107692
# 3       107699
# 4       111232
#         ...
# 902    2722097
# 903    2734110
# 904    2742307
# 905    2744611
# 906    2761886
# Name: sample, Length: 907, dtype: int64
# [DONE] Events | R1092J | FR1 | 3
# 0        50895
# 1       256004
# 2       266432
# 3       266440
# 4       270023
#         ...
# 806    3807922
# 807    3809108
# 808    3810285
# 809    3812044
# 810    3836907
# Name: sample, Length: 811, dtype: int64
# [DONE] Events | R1108J | FR1 | 0
# 0         8343
# 1        95503
# 2       105930
# 3       105938
# 4       109504
#         ...
# 821    3986978
# 822    3995246
# 823    4009684
# 824    4013365
# 825    4025944
# Name: sample, Length: 826, dtype: int64
# [DONE] Events | R1108J | FR1 | 1
# 0        11449
# 1       155299
# 2       165727
# 3       169602
# 4       172151
#         ...
# 377    1948705
# 378    1983752
# 379    1983752
# 380    1994180
# 381    1994186
# Name: sample, Length: 382, dtype: int64
# [DONE] Events | R1108J | FR1 | 2
# 0         7486
# 1        31657
# 2        42085
# 3        42090
# 4        45625
#         ...
# 693    2961360
# 694    2962623
# 695    2964294
# 696    2991369
# 697    3005849
# Name: sample, Length: 698, dtype: int64
# [DONE] Events | R1108J | FR1 | 3
# 0        23207
# 1        32311
# 2        37524
# 3        39379
# 4        40579
#         ...
# 760    1435126
# 761    1442760
# 762    1583983
# 763    1583983
# 764         -1
# Name: sample, Length: 765, dtype: int64
# [DONE] Events | R1111M | FR1 | 0
# 0        28986
# 1        38640
# 2        43853
# 3        45741
# 4        46949
#         ...
# 531    1048894
# 532    1048894
# 533    1063901
# 534    1135981
# 535    1135981
# Name: sample, Length: 536, dtype: int64
# [DONE] Events | R1111M | FR1 | 1
# 0       106343
# 1       125671
# 2       130885
# 3       132830
# 4       134056
#         ...
# 863    1516538
# 864    1524034
# 865    1524770
# 866    1527015
# 867    1552425
# Name: sample, Length: 868, dtype: int64
# [DONE] Events | R1111M | FR1 | 2
# 0        26228
# 1        41979
# 2        47193
# 3        49171
# 4        50455
#         ...
# 683    1151981
# 684    1153369
# 685    1159110
# 686    1165656
# 687    1165657
# Name: sample, Length: 688, dtype: int64
# [DONE] Events | R1111M | FR1 | 3
# [SKIP] Events | R1207J | FR1 | 0
# [SKIP] Events | R1207J | FR1 | 1
# 0        78905
# 1        78905
# 2        89770
# 3        89770
# 4       109769
#         ...
# 852    2084593
# 853    2085443
# 854    2087059
# 855    2087059
# 856    2087060
# Name: sample, Length: 857, dtype: int64
# [DONE] Events | R1226D | FR1 | 0
# 0         44004
# 1         44004
# 2         55057
# 3         55057
# 4         69057
#          ...
# 1195    3113259
# 1196    3113862
# 1197    3121358
# 1198    3123222
# 1199    3126354
# Name: sample, Length: 1200, dtype: int64
# [DONE] Events | R1226D | FR1 | 1
# [SKIP] Events | R1230J | FR1 | 0
# [SKIP] Events | R1230J | FR1 | 2
# [SKIP] Events | R1230J | FR1 | 4
# [SKIP] Events | R1230J | FR1 | 5
# [SKIP] Events | R1230J | FR1 | 6

# %% [markdown]
# ### 3d. Run Montage comparison (iEEG only)

# %%
for _, row in df_ram.iterrows():
    sub, exp, sess = row["subject"], row["experiment"], int(row["session"])
    loc = int(row["localization"])
    mon = int(row["montage"])

    try:
        result = MontagePipeline(
            sub, exp, sess, ram_bids_root, ram_out_path,
            skip_if_exists=SKIP_IF_EXISTS,
            localization=loc, montage=mon,
        ).run()
        tag = "SKIP" if result.get("skipped") else "DONE"
        print(f"[{tag}] Montage | {sub} | {exp} | {sess}")
    except Exception as e:
        print(f"[FAIL] Montage | {sub} | {exp} | {sess}: {e}")
# Out:
# [DONE] Montage | R1060M | FR1 | 0
# [DONE] Montage | R1060M | FR1 | 1
# [DONE] Montage | R1060M | FR1 | 2
# [DONE] Montage | R1060M | FR1 | 3
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# [DONE] Montage | R1061T | FR1 | 0
# [DONE] Montage | R1061T | FR1 | 1
# [DONE] Montage | R1061T | FR1 | 2
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# [DONE] Montage | R1061T | FR1 | 3
# [DONE] Montage | R1065J | FR1 | 0
# [DONE] Montage | R1065J | FR1 | 1
# [DONE] Montage | R1065J | FR1 | 2
# [DONE] Montage | R1065J | FR1 | 3
# [DONE] Montage | R1065J | FR1 | 4
# [DONE] Montage | R1065J | FR1 | 5
# [DONE] Montage | R1066P | FR1 | 0
# [DONE] Montage | R1066P | FR1 | 1
# [DONE] Montage | R1066P | FR1 | 2
# [DONE] Montage | R1066P | FR1 | 3
# [DONE] Montage | R1092J | FR1 | 0
# [DONE] Montage | R1092J | FR1 | 1
# [DONE] Montage | R1092J | FR1 | 2
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# [DONE] Montage | R1092J | FR1 | 3
# [DONE] Montage | R1108J | FR1 | 0
# [DONE] Montage | R1108J | FR1 | 1
# [DONE] Montage | R1108J | FR1 | 2
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# [DONE] Montage | R1108J | FR1 | 3
# [DONE] Montage | R1111M | FR1 | 0
# [DONE] Montage | R1111M | FR1 | 1
# [DONE] Montage | R1111M | FR1 | 2
# [DONE] Montage | R1111M | FR1 | 3
# [DONE] Montage | R1207J | FR1 | 0
# [DONE] Montage | R1207J | FR1 | 1
# [DONE] Montage | R1226D | FR1 | 0
# [DONE] Montage | R1226D | FR1 | 1
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/cmlreaders/readers/electrodes.py:241: MissingCoordinatesWarning: Could not load MNI coordinates
#   warnings.warn(cmlreaders.warnings.MissingCoordinatesWarning(
# [DONE] Montage | R1230J | FR1 | 0
# [DONE] Montage | R1230J | FR1 | 2
# [DONE] Montage | R1230J | FR1 | 4
# [DONE] Montage | R1230J | FR1 | 5
# [DONE] Montage | R1230J | FR1 | 6

# %% [markdown]
# ### 3e. Aggregate RAM results & plot

# %%
ram_final = "ram_final/"
os.makedirs(ram_final, exist_ok=True)

FILE_CATEGORIES_RAM = [
    "df_raw", "df_raw_summary", "df_time",
    "df_behavior_summary",
    "df_epoch", "df_epoch_summary", "df_epoch_time",
    "df_contacts_summary", "df_contacts_column_summary", "df_contacts_mismatches",
    "df_pairs_summary", "df_pairs_column_summary", "df_pairs_mismatches",
    "df_montage_summary",
]

ram_dfs = {}
for cat in FILE_CATEGORIES_RAM:
    files = [
        os.path.join(dp, f)
        for dp, _, fns in os.walk(ram_out_path)
        for f in fns
        if f.endswith(".csv") and f.startswith(cat + "_")
    ]
    if not files:
        print(f"Skipping {cat} (no files)")
        continue
    df_all = load_and_concat(files)
    ram_dfs[cat] = df_all
    outfile = os.path.join(ram_final, f"{cat}_all.csv")
    df_all.to_csv(outfile, index=False)
    print(f"{cat}: {len(files)} files -> {outfile}")
# Out:
# Skipping df_raw (no files)
# Skipping df_raw_summary (no files)
# Skipping df_time (no files)
# df_behavior_summary: 32 files -> ram_final/df_behavior_summary_all.csv
# Skipping df_epoch (no files)
# Skipping df_epoch_summary (no files)
# Skipping df_epoch_time (no files)
# df_contacts_summary: 32 files -> ram_final/df_contacts_summary_all.csv
# df_contacts_column_summary: 32 files -> ram_final/df_contacts_column_summary_all.csv
# Warning: skipping ram_results/df_contacts_mismatches_R1060M_FR1_0.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1060M_FR1_1.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1060M_FR1_2.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1060M_FR1_3.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1061T_FR1_0.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1061T_FR1_1.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1061T_FR1_2.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1061T_FR1_3.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1065J_FR1_0.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1065J_FR1_1.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1065J_FR1_2.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1065J_FR1_3.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1065J_FR1_4.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1065J_FR1_5.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1066P_FR1_0.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1066P_FR1_1.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1066P_FR1_2.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1066P_FR1_3.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1092J_FR1_0.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1092J_FR1_1.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1092J_FR1_2.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1092J_FR1_3.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1108J_FR1_0.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1108J_FR1_1.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1108J_FR1_2.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1108J_FR1_3.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1111M_FR1_0.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1111M_FR1_1.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1111M_FR1_2.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1111M_FR1_3.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1226D_FR1_0.csv: No columns to parse from file
# Warning: skipping ram_results/df_contacts_mismatches_R1226D_FR1_1.csv: No columns to parse from file
# df_contacts_mismatches: 32 files -> ram_final/df_contacts_mismatches_all.csv
# df_pairs_summary: 32 files -> ram_final/df_pairs_summary_all.csv
# df_pairs_column_summary: 32 files -> ram_final/df_pairs_column_summary_all.csv
# df_pairs_mismatches: 32 files -> ram_final/df_pairs_mismatches_all.csv
# Removed 1 duplicate rows
# df_montage_summary: 40 files -> ram_final/df_montage_summary_all.csv

# %%
# --- Raw signal plots ---
if "df_raw_summary" in ram_dfs:
    plot_comparison_results(ram_dfs["df_raw_summary"], "mean_abs_diff", "std_diff", col_label="Mean Abs Signal Diff")
    plot_comparison_results(ram_dfs["df_raw_summary"], "mse", col_label="MSE Raw Signal")
    plot_comparison_results(ram_dfs["df_raw_summary"], "n_exact_diff_channels")
    plot_comparison_results(ram_dfs["df_raw_summary"], "n_close_diff_channels")

# --- Time coord plots ---
if "df_time" in ram_dfs:
    plot_comparison_results(ram_dfs["df_time"], "mean_abs_time_diff", "std_time_diff", col_label="Mean Abs Time Diff")
    plot_comparison_results(ram_dfs["df_time"], "mse_time", col_label="MSE Time")

# --- Behavioral plots ---
if "df_behavior_summary" in ram_dfs:
    plot_comparison_results(ram_dfs["df_behavior_summary"], "n_differing_columns")
